# %%
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import tree
import datetime as dt
import pandas as pd
import numpy as np
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.patches import Patch
import os
from shutil import copy
import seaborn as sns
import scipy.stats as stats
import datetime
from dateutil.relativedelta import relativedelta
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pickle
import imageio
from itertools import compress

# %matplotlib inline

pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams.update({'figure.max_open_warning': 0})

import matplotlib.pylab as pylab
params = {'legend.fontsize': 'xx-large',
          'legend.title_fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
#‘xx-small’, ‘x-small’, ‘small’, ‘medium’, ‘large’, ‘x-large’, ‘xx-large’
pylab.rcParams.update(params)
from sklearn.ensemble import IsolationForest
from sklearn.decomposition import PCA
# from mpl_toolkits.mplot3d import Axes3D
import plotly.express as px
from statsmodels.tsa.api import VAR

from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn import tree

import re

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
df_smolt_data = pd.read_csv('smolt_dataset.csv',delimiter=";")

df_smolt_data.insert(loc = 51, column = 'date_conf', value = np.nan)
df_smolt_data.reset_index(drop = True, inplace = True)
df_smolt_data ['transfer_date']= pd.to_datetime(df_smolt_data['transfer_date'])
df_smolt_data ['date_conf']= pd.to_datetime(df_smolt_data['date_conf'])                                                               
m = 0
while m < len(df_smolt_data):
    days_btw_transfer_conf = df_smolt_data.iloc[m] [50]
    print('days_btw_transfer_conf', days_btw_transfer_conf)
    if np.isnan(days_btw_transfer_conf) == True:
        df_smolt_data.iloc[m] [51] = np.nan
    else:    
        transfer_date = df_smolt_data.iloc[m] ['transfer_date']
        df_smolt_data.at[m, 'date_conf'] = transfer_date - dt.timedelta(days = int(days_btw_transfer_conf))
    m = m + 1
    
#df_smolt_data.to_csv(r'/Users/evgenijnotebook/Desktop/Salmon_project/data/smolt_dataset_wth_date_conf.csv', index = False)
# Out:
# days_btw_transfer_conf nan
# days_btw_transfer_conf 56.0
# days_btw_transfer_conf 49.0
# days_btw_transfer_conf nan
# days_btw_transfer_conf 93.0
# days_btw_transfer_conf nan
# days_btw_transfer_conf 90.0
# days_btw_transfer_conf 58.0
# days_btw_transfer_conf 65.0
# days_btw_transfer_conf 26.0
# days_btw_transfer_conf 86.0
# days_btw_transfer_conf 110.0
# days_btw_transfer_conf 120.0
# days_btw_transfer_conf 89.0
# days_btw_transfer_conf 50.0
# days_btw_transfer_conf nan
# days_btw_transfer_conf 70.0
# days_btw_transfer_conf 84.0
# days_btw_transfer_conf 85.0
# days_btw_transfer_conf 67.0
# days_btw_transfer_conf 79.0
# days_btw_transfer_conf 48.0
# days_btw_transfer_conf 120.0
# days_btw_transfer_conf 76.0
# days_btw_transfer_conf nan
# days_btw_transfer_conf 46.0
# days_btw_transfer_conf 54.0
# days_btw_transfer_conf 71.0
# days_btw_transfer_conf 121.0
# days_btw_transfer_conf 82.0
# days_btw_transfer_conf 53.0
# days_btw_transfer_conf 87.0
# days_btw_transfer_conf 66.0
# days_btw_transfer_conf 123.0
# days_btw_transfer_conf 89.0
# days_btw_transfer_conf 99.0
# days_btw_transfer_conf 45.0
# days_btw_transfer_conf 55.0
# days_btw_transfer_conf 66.0
# days_btw_transfer_conf 50.0
# days_btw_transfer_conf 54.0
# days_btw_transfer_conf 78.0
# days_btw_transfer_conf nan
# days_btw_transfer_conf 62.0
# days_btw_transfer_conf 91.0
# days_btw_transfer_conf nan
# days_btw_transfer_conf 55.0
# days_btw_transfer_conf 115.0
# days_btw_transfer_conf 78.0
# days_btw_transfer_conf 121.0
# days_btw_transfer_conf 97.0
# days_btw_transfer_conf 49.0
# days_btw_transfer_conf 48.0
# days_btw_transfer_conf nan
# days_btw_transfer_conf 54.0
# days_btw_transfer_conf 49.0
# days_btw_transfer_conf 48.0
# days_btw_transfer_conf 85.0
# days_btw_transfer_conf 48.0
# days_btw_transfer_conf nan
# days_btw_transfer_conf 49.0
# days_btw_transfer_conf 52.0
# days_btw_transfer_conf 61.0
# days_btw_transfer_conf 51.0
# days_btw_transfer_conf 91.0
# days_btw_transfer_conf 69.0
# days_btw_transfer_conf 73.0
# days_btw_transfer_conf nan
# days_btw_transfer_conf 135.0
# days_btw_transfer_conf 49.0
# days_btw_transfer_conf 145.0
# days_btw_transfer_conf 71.0
# days_btw_transfer_conf 62.0
# days_btw_transfer_conf 95.0
# days_btw_transfer_conf 55.0
# days_btw_transfer_conf 68.0
# days_btw_transfer_conf 127.0
# days_btw_transfer_conf 56.0
# days_btw_transfer_conf 87.0
# days_btw_transfer_conf 93.0
# days_btw_transfer_conf 43.0
# days_btw_transfer_conf nan
# days_btw_transfer_conf 85.0
# days_btw_transfer_conf 72.0
# days_btw_transfer_conf nan
# days_btw_transfer_conf 102.0
# days_btw_transfer_conf 49.0
# days_btw_transfer_conf nan
# days_btw_transfer_conf 73.0
# days_btw_transfer_conf 110.0
# days_btw_transfer_conf 45.0
# days_btw_transfer_conf 121.0
# days_btw_transfer_conf 62.0
# days_btw_transfer_conf 123.0
# days_btw_transfer_conf 96.0
# days_btw_transfer_conf 51.0
# days_btw_transfer_conf 54.0
# days_btw_transfer_conf 62.0
# days_btw_transfer_conf 70.0
# days_btw_transfer_conf 73.0
# days_btw_transfer_conf nan
# days_btw_transfer_conf 87.0
# days_btw_transfer_conf 47.0
# days_btw_transfer_conf nan
# days_btw_transfer_conf 48.0
# days_btw_transfer_conf 112.0
# days_btw_transfer_conf 96.0
# days_btw_transfer_conf nan
# days_btw_transfer_conf 76.0
# days_btw_transfer_conf 56.0
# days_btw_transfer_conf nan
# days_btw_transfer_conf 68.0
# days_btw_transfer_conf 69.0
# days_btw_transfer_conf 93.0
# days_btw_transfer_conf 59.0
# days_btw_transfer_conf 69.0
# days_btw_transfer_conf
# days_btw_transfer_conf 56.0
# days_btw_transfer_conf 56.0
# days_btw_transfer_conf 66.0
# days_btw_transfer_conf 83.0
# days_btw_transfer_conf 73.0
# days_btw_transfer_conf 63.0
# days_btw_transfer_conf 83.0
# days_btw_transfer_conf 74.0
# days_btw_transfer_conf 75.0
# days_btw_transfer_conf 53.0
# days_btw_transfer_conf 66.0
# days_btw_transfer_conf 53.0
# days_btw_transfer_conf 64.0
# days_btw_transfer_conf 73.0
# days_btw_transfer_conf 83.0
# days_btw_transfer_conf 74.0
# days_btw_transfer_conf 74.0
# days_btw_transfer_conf 77.0
# days_btw_transfer_conf 66.0
# days_btw_transfer_conf 64.0
# days_btw_transfer_conf 73.0
# days_btw_transfer_conf 75.0

# %%
df_smolt_data
# Out:
#       locus_id  fish_group_id  transfer_year  transfer_month  \
# 0      3046036             11           2017               1
# 1      3046036           1052           2019               1
# 2      3046036           3918           2020              11
# 3      3046043            310           2017               6
# 4      3046043            498           2019               7
# ...        ...            ...            ...             ...
# 1086   7183889           6071           2022               6
# 1087   7183890           6072           2022               6
# 1088   7183891           6072           2022               6
# 1089   7183892           6069           2022               6
# 1090   7183893           6069           2022               6
#
#      transfer_month_year transfer_season  total_count total_mortality_perc_90  \
# 0                 1_2017          winter    44934,175             0,007496165
# 1                 1_2019          winter  46388,23077             0,003942904
# 2                11_2020          autumn  45241,16667             0,007676062
# 3                 6_2017          summer  38451,42593             0,018393697
# 4                 7_2019          summer  41131,79661             0,027013536
# ...                  ...             ...          ...                     ...
# 1086              6_2022          summer  44747,76389             0,012812974
# 1087              6_2022          summer  44563,77612             0,014813398
# 1088              6_2022          summer  44585,79167              0,01465357
# 1089              6_2022          summer  44244,95833             0,022575856
# 1090              6_2022          summer  43669,97015             0,035173785
#
#      transport_mortality_perc_90 nontransport_mortality_perc_90  ...  \
# 0                    0,001309054                    0,006187111  ...
# 1                    0,000924979                    0,003017925  ...
# 2                    0,005640632                    0,002035429  ...
# 3                    0,006842934                    0,011550763  ...
# 4                    0,022782874                    0,004230661  ...
# ...                          ...                            ...  ...
# 1086                 0,002758736                    0,010054239  ...
# 1087                 0,008025966                    0,006787432  ...
# 1088                 0,007419565                    0,007234005  ...
# 1089                 0,015284297                    0,007291559  ...
# 1090                 0,028200436                    0,006973349  ...
#
#       date_conf          SGR          TGC  order_of_creation_from  strain  \
# 0           NaT          NaN          NaN                       6     FAN
# 1    2018-11-20  0,863440282  0,951440321                       5     FLY
# 2    2020-09-30  0,972984604  1,181745984                      11     FLY
# 3           NaT          NaN          NaN                      10     FLY
# 4    2019-04-24  0,800972852  0,883692915                       3     LCY
# ...         ...          ...          ...                     ...     ...
# 1086 2022-04-08  0,692506163  0,768343162                       3     FLY
# 1087 2022-07-02  0,862384041  0,958244367                       3     FLY
# 1088 2022-07-04  0,695116331  0,801179534                       3     FLY
# 1089 2022-03-25   0,79240455   0,87628003                       3     FLY
# 1090 2022-03-23  0,874297558   1,00176444                       3     FLY
#
#       year_class number_of_prod_cycle  place_first_feeding  \
# 0             16                   C1                   PH
# 1             18                  C1B                   PH
# 2             19                   C4                   PH
# 3             16                  C2B                   PH
# 4             18                   C3                  PGR
# ...          ...                  ...                  ...
# 1086          21                   C2                   PH
# 1087          21                   C2                   PH
# 1088          21                   C2                   PH
# 1089          21                   C2                   PH
# 1090          21                   C2                   PH
#
#       specific_treatment  two_place_of_first_feeding
# 0                   None                           0
# 1                   None                           0
# 2                    LUF                           0
# 3                   None                           0
# 4                   None                           1
# ...                  ...                         ...
# 1086                 LUF                           0
# 1087                 LUF                           0
# 1088                 LUF                           0
# 1089                 LUF                           0
# 1090                 LUF                           0
#
# [1091 rows x 61 columns]

# %%
temperatures=pd.read_csv("FW_temperature_cleared.csv")

# %%
temperatures.columns
# Out:
# Index(['final_locus_population_id', 'event_date', 'temperature_cleared',
#        'temperature', 'rolling_tempr'],
#       dtype='object')

# %%
temperatures.head()
# Out:
#    final_locus_population_id  event_date  temperature_cleared  temperature  \
# 0                   36783130  2017-09-01            15.900242    15.900242
# 1                   36783130  2017-09-02            15.900242    15.900242
# 2                   36783130  2017-09-03            15.600239    15.600239
# 3                   36783130  2017-09-04            15.800241    15.800241
# 4                   36783130  2017-09-05            15.833575    15.833575
#
#    rolling_tempr
# 0      15.900242
# 1      15.900242
# 2      15.600239
# 3      15.800241
# 4      15.833575

# %%
temperatures[temperatures.final_locus_population_id.isin([36794892])]
# Out:
#        final_locus_population_id  event_date  temperature_cleared  \
# 85608                   36794892  2018-08-29             7.538574
# 85609                   36794892  2018-08-30             8.000732
# 85610                   36794892  2018-08-31             8.100742
# 85611                   36794892  2018-09-01             8.700796
# 85612                   36794892  2018-09-02             8.500778
# ...                          ...         ...                  ...
# 85975                   36794892  2019-08-31            13.000000
# 85976                   36794892  2019-09-01            12.800000
# 85977                   36794892  2019-09-02            12.200000
# 85978                   36794892  2019-09-03            11.800000
# 85979                   36794892  2019-09-04            11.800000
#
#        temperature  rolling_tempr
# 85608     7.538574       7.538574
# 85609     8.000732       8.000732
# 85610     8.100742       8.100742
# 85611     8.700796       8.700796
# 85612     8.500778       8.500778
# ...            ...            ...
# 85975    13.000000      12.926667
# 85976    12.800000      12.906667
# 85977    12.200000      12.883333
# 85978    11.800000      12.846667
# 85979    11.800000      12.810000
#
# [372 rows x 5 columns]

# %%
from_locus_population_id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-a54a7c1b49bf> in <module>
# ----> 1 from_locus_population_id
#
# NameError: name 'from_locus_population_id' is not defined

# %%
df_smolt_data['transfer_date'] = pd.to_datetime(df_smolt_data['transfer_date'])
df_smolt_data['date_conf'] = pd.to_datetime(df_smolt_data['date_conf'])
temperatures['date'] = pd.to_datetime(temperatures['event_date'])

# %%
merged_df = df_smolt_data.merge(temperatures, left_on='from_locus_population_id', right_on='final_locus_population_id')

# %%
sums_by_id = {}

# %%
grouped_df = merged_df.groupby('from_locus_population_id')

# %%
for group_id, group_data in grouped_df:
    filtered_data = group_data[group_data.apply(lambda row: row['date'] <= row['transfer_date'] and row['date'] >= row['date_conf'], axis=1)]
    sum_of_tempr = filtered_data['rolling_tempr'].sum()
    sums_by_id[group_id] = sum_of_tempr

# %%
for group_id, sum_of_tempr in sums_by_id.items():
    print(f"Sum of 'rolling_tempr' for group {group_id}: {sum_of_tempr}")
# Out:
# Sum of 'rolling_tempr' for group 36783130: 3972.298327166667
# Sum of 'rolling_tempr' for group 36783339: 3748.164120666667
# Sum of 'rolling_tempr' for group 36783413: 278.68
# Sum of 'rolling_tempr' for group 36783453: 252.37333333333333
# Sum of 'rolling_tempr' for group 36783456: 0.0
# Sum of 'rolling_tempr' for group 36783638: 882.8177266333333
# Sum of 'rolling_tempr' for group 36783641: 0.0
# Sum of 'rolling_tempr' for group 36783876: 0.0
# Sum of 'rolling_tempr' for group 36783881: 0.0
# Sum of 'rolling_tempr' for group 36783885: 764.0349508500001
# Sum of 'rolling_tempr' for group 36783890: 3311.3559606
# Sum of 'rolling_tempr' for group 36783892: 0.0
# Sum of 'rolling_tempr' for group 36783897: 1002.4402015333332
# Sum of 'rolling_tempr' for group 36783904: 865.0845924333335
# Sum of 'rolling_tempr' for group 36783918: 0.0
# Sum of 'rolling_tempr' for group 36783943: 2875.8156448000004
# Sum of 'rolling_tempr' for group 36783984: 0.0
# Sum of 'rolling_tempr' for group 36783987: 1130.6835373
# Sum of 'rolling_tempr' for group 36784208: 1488.1138165333332
# Sum of 'rolling_tempr' for group 36784215: 1439.3989483999999
# Sum of 'rolling_tempr' for group 36784356: 0.0
# Sum of 'rolling_tempr' for group 36784446: 1445.6593120000002
# Sum of 'rolling_tempr' for group 36784663: 2267.3042514500003
# Sum of 'rolling_tempr' for group 36784891: 1010.3826238000001
# Sum of 'rolling_tempr' for group 36784897: 929.5597079166666
# Sum of 'rolling_tempr' for group 36784904: 1002.4402015333332
# Sum of 'rolling_tempr' for group 36784949: 1130.6735373
# Sum of 'rolling_tempr' for group 36785116: 0.0
# Sum of 'rolling_tempr' for group 36785126: 774.2518695416667
# Sum of 'rolling_tempr' for group 36785136: 0.0
# Sum of 'rolling_tempr' for group 36785145: 0.0
# Sum of 'rolling_tempr' for group 36785156: 754.7526016333334
# Sum of 'rolling_tempr' for group 36785177: 0.0
# Sum of 'rolling_tempr' for group 36785232: 0.0
# Sum of 'rolling_tempr' for group 36785256: 965.9223641333333
# Sum of 'rolling_tempr' for group 36785272: 1527.9499016999998
# Sum of 'rolling_tempr' for group 36785291: 675.3723059
# Sum of 'rolling_tempr' for group 36785295: 856.2709437
# Sum of 'rolling_tempr' for group 36785300: 0.0
# Sum of 'rolling_tempr' for group 36785514: 1050.1463745833335
# Sum of 'rolling_tempr' for group 36785517: 1443.6601046
# Sum of 'rolling_tempr' for group 36785537: 372.90333333333336
# Sum of 'rolling_tempr' for group 36785552: 1458.9552648666668
# Sum of 'rolling_tempr' for group 36785661: 628.2722256833333
# Sum of 'rolling_tempr' for group 36785665: 710.5290769999999
# Sum of 'rolling_tempr' for group 36785674: 1907.9105082666665
# Sum of 'rolling_tempr' for group 36785689: 3624.5744393
# Sum of 'rolling_tempr' for group 36785698: 1286.6137427355557
# Sum of 'rolling_tempr' for group 36785748: 1182.8333977666666
# Sum of 'rolling_tempr' for group 36785840: 1780.8863223
# Sum of 'rolling_tempr' for group 36785852: 2053.6261495
# Sum of 'rolling_tempr' for group 36785877: 1354.5
# Sum of 'rolling_tempr' for group 36785886: 841.575
# Sum of 'rolling_tempr' for group 36785914: 756.4748024000002
# Sum of 'rolling_tempr' for group 36785936: 699.0113433
# Sum of 'rolling_tempr' for group 36785937: 680.9831966499999
# Sum of 'rolling_tempr' for group 36785940: 862.028579
# Sum of 'rolling_tempr' for group 36785946: 662.4943316333333
# Sum of 'rolling_tempr' for group 36785947: 907.9491443166667
# Sum of 'rolling_tempr' for group 36786117: 729.8969749666667
# Sum of 'rolling_tempr' for group 36786317: 1023.2093860583334
# Sum of 'rolling_tempr' for group 36786324: 815.7577363666667
# Sum of 'rolling_tempr' for group 36786344: 615.5165350333333
# Sum of 'rolling_tempr' for group 36786363: 0.0
# Sum of 'rolling_tempr' for group 36786441: 0.0
# Sum of 'rolling_tempr' for group 36786459: 835.2071993166667
# Sum of 'rolling_tempr' for group 36786466: 835.2069696833335
# Sum of 'rolling_tempr' for group 36786693: 609.4555915999998
# Sum of 'rolling_tempr' for group 36786697: 653.5719371
# Sum of 'rolling_tempr' for group 36786702: 648.04514205
# Sum of 'rolling_tempr' for group 36786742: 372.9066666666667
# Sum of 'rolling_tempr' for group 36786821: 774.3231918333333
# Sum of 'rolling_tempr' for group 36786834: 936.7909708533334
# Sum of 'rolling_tempr' for group 36786850: 2280.3542209
# Sum of 'rolling_tempr' for group 36786851: 1899.5708594
# Sum of 'rolling_tempr' for group 36786853: 941.6460074833335
# Sum of 'rolling_tempr' for group 36786859: 0.0
# Sum of 'rolling_tempr' for group 36786864: 373.12376079999996
# Sum of 'rolling_tempr' for group 36786878: 962.4937914833333
# Sum of 'rolling_tempr' for group 36786909: 405.38000000000005
# Sum of 'rolling_tempr' for group 36786950: 2024.8358541444443
# Sum of 'rolling_tempr' for group 36786953: 2798.058370366667
# Sum of 'rolling_tempr' for group 36787193: 1805.2618564999998
# Sum of 'rolling_tempr' for group 36787196: 2072.252715377778
# Sum of 'rolling_tempr' for group 36787205: 609.4455915999998
# Sum of 'rolling_tempr' for group 36787272: 615.5265350333334
# Sum of 'rolling_tempr' for group 36787336: 1023.4526251999998
# Sum of 'rolling_tempr' for group 36787395: 856.2598640211111
# Sum of 'rolling_tempr' for group 36787414: 649.2028439833334
# Sum of 'rolling_tempr' for group 36787454: 640.3047418833332
# Sum of 'rolling_tempr' for group 36787518: 855.9135805034446
# Sum of 'rolling_tempr' for group 36787545: 930.4403800777778
# Sum of 'rolling_tempr' for group 36787564: 870.9203885085
# Sum of 'rolling_tempr' for group 36787612: 558.5988888888888
# Sum of 'rolling_tempr' for group 36787653: 1906.4422157006666
# Sum of 'rolling_tempr' for group 36787662: 545.2922222222222
# Sum of 'rolling_tempr' for group 36787680: 993.1119338277779
# Sum of 'rolling_tempr' for group 36787705: 966.07962245
# Sum of 'rolling_tempr' for group 36787713: 1182.8333977666666
# Sum of 'rolling_tempr' for group 36787983: 854.7800000000001
# Sum of 'rolling_tempr' for group 36787990: 1925.8866666666665
# Sum of 'rolling_tempr' for group 36788024: 899.1124356
# Sum of 'rolling_tempr' for group 36788133: 1548.6530503333333
# Sum of 'rolling_tempr' for group 36788343: 958.5134111666666
# Sum of 'rolling_tempr' for group 36788345: 888.9303131833333
# Sum of 'rolling_tempr' for group 36788385: 960.6806691833334
# Sum of 'rolling_tempr' for group 36788452: 1064.5440329833332
# Sum of 'rolling_tempr' for group 36788455: 2129.043956833333
# Sum of 'rolling_tempr' for group 36788463: 902.63092825
# Sum of 'rolling_tempr' for group 36788625: 993.0986004944446
# Sum of 'rolling_tempr' for group 36788641: 199.26666666666668
# Sum of 'rolling_tempr' for group 36788726: 2009.1928202666668
# Sum of 'rolling_tempr' for group 36789043: 1322.6138264666665
# Sum of 'rolling_tempr' for group 36789064: 1349.6502059
# Sum of 'rolling_tempr' for group 36789213: 1211.0888833333333
# Sum of 'rolling_tempr' for group 36789269: 1212.0353783333333
# Sum of 'rolling_tempr' for group 36789288: 901.5455825666668
# Sum of 'rolling_tempr' for group 36789341: 983.5953189222222
# Sum of 'rolling_tempr' for group 36789388: 1982.8983187999997
# Sum of 'rolling_tempr' for group 36789535: 1377.715016311111
# Sum of 'rolling_tempr' for group 36789589: 3260.7055053
# Sum of 'rolling_tempr' for group 36789600: 3011.0731144499996
# Sum of 'rolling_tempr' for group 36789691: 1018.4567577
# Sum of 'rolling_tempr' for group 36789702: 994.6312890555556
# Sum of 'rolling_tempr' for group 36789724: 783.7618
# Sum of 'rolling_tempr' for group 36789742: 1569.6441488666667
# Sum of 'rolling_tempr' for group 36789743: 2291.532396366667
# Sum of 'rolling_tempr' for group 36789780: 683.0721156666667
# Sum of 'rolling_tempr' for group 36789845: 920.4568822944444
# Sum of 'rolling_tempr' for group 36789963: 2129.088065966667
# Sum of 'rolling_tempr' for group 36789988: 0.0
# Sum of 'rolling_tempr' for group 36790002: 1064.5219784166663
# Sum of 'rolling_tempr' for group 36790211: 2084.155423633333
# Sum of 'rolling_tempr' for group 36790239: 2329.6898493999997
# Sum of 'rolling_tempr' for group 36790290: 0.0
# Sum of 'rolling_tempr' for group 36790496: 688.6814271833334
# Sum of 'rolling_tempr' for group 36790509: 1968.2003576
# Sum of 'rolling_tempr' for group 36790515: 653.9377064166667
# Sum of 'rolling_tempr' for group 36790517: 736.81809385
# Sum of 'rolling_tempr' for group 36790525: 931.8559467333333
# Sum of 'rolling_tempr' for group 36790612: 1567.5302666666664
# Sum of 'rolling_tempr' for group 36790638: 2314.5158745999997
# Sum of 'rolling_tempr' for group 36790645: 3239.4381112500005
# Sum of 'rolling_tempr' for group 36790663: 185.8466666666667
# Sum of 'rolling_tempr' for group 36790772: 1499.6112210166666
# Sum of 'rolling_tempr' for group 36790828: 688.6780938500001
# Sum of 'rolling_tempr' for group 36790888: 654.8064469833334
# Sum of 'rolling_tempr' for group 36790899: 0.0
# Sum of 'rolling_tempr' for group 36790914: 1923.9863602599999
# Sum of 'rolling_tempr' for group 36790921: 2479.132989933333
# Sum of 'rolling_tempr' for group 36790927: 993.32522294
# Sum of 'rolling_tempr' for group 36790972: 1967.1839711777777
# Sum of 'rolling_tempr' for group 36790999: 225.54333333333332
# Sum of 'rolling_tempr' for group 36791012: 1424.7755321555555
# Sum of 'rolling_tempr' for group 36791013: 698.9899999999999
# Sum of 'rolling_tempr' for group 36791015: 1416.3290387944444
# Sum of 'rolling_tempr' for group 36791264: 1068.5673627233332
# Sum of 'rolling_tempr' for group 36791270: 1270.775743188889
# Sum of 'rolling_tempr' for group 36791444: 1989.1959114444446
# Sum of 'rolling_tempr' for group 36791478: 1018.4567577
# Sum of 'rolling_tempr' for group 36792115: 0.0
# Sum of 'rolling_tempr' for group 36792144: 1300.4588693611115
# Sum of 'rolling_tempr' for group 36792146: 1662.1197341773334
# Sum of 'rolling_tempr' for group 36792148: 2950.666807255556
# Sum of 'rolling_tempr' for group 36792238: 1174.0817384522225
# Sum of 'rolling_tempr' for group 36792259: 931.8326134
# Sum of 'rolling_tempr' for group 36792294: 367.0383333333333
# Sum of 'rolling_tempr' for group 36792307: 1636.8633368013334
# Sum of 'rolling_tempr' for group 36792315: 1007.7928027
# Sum of 'rolling_tempr' for group 36792334: 298.7416666666667
# Sum of 'rolling_tempr' for group 36792351: 984.1068454666666
# Sum of 'rolling_tempr' for group 36792491: 2035.7363256777776
# Sum of 'rolling_tempr' for group 36792705: 1794.0935322666667
# Sum of 'rolling_tempr' for group 36792716: 3690.1595976666667
# Sum of 'rolling_tempr' for group 36792866: 3919.69526958
# Sum of 'rolling_tempr' for group 36792889: 4139.654159420001
# Sum of 'rolling_tempr' for group 36792900: 1233.1982784000002
# Sum of 'rolling_tempr' for group 36793076: 813.028882
# Sum of 'rolling_tempr' for group 36793085: 813.0661010666666
# Sum of 'rolling_tempr' for group 36793233: 1876.7989362144442
# Sum of 'rolling_tempr' for group 36793345: 1649.7875967277778
# Sum of 'rolling_tempr' for group 36793414: 0.0
# Sum of 'rolling_tempr' for group 36793429: 1204.7883343777778
# Sum of 'rolling_tempr' for group 36793472: 1602.9910799544446
# Sum of 'rolling_tempr' for group 36793493: 1285.3137030616667
# Sum of 'rolling_tempr' for group 36793562: 1590.495137972222
# Sum of 'rolling_tempr' for group 36793611: 1169.5792075166669
# Sum of 'rolling_tempr' for group 36793637: 1300.4255360277782
# Sum of 'rolling_tempr' for group 36793739: 3725.5628795000002
# Sum of 'rolling_tempr' for group 36793742: 2471.5725029666664
# Sum of 'rolling_tempr' for group 36793763: 1322.5893441555559
# Sum of 'rolling_tempr' for group 36793796: 1261.474583711111
# Sum of 'rolling_tempr' for group 36793852: 2829.2162480444445
# Sum of 'rolling_tempr' for group 36793911: 4816.340487466667
# Sum of 'rolling_tempr' for group 36793936: 1609.711989155556
# Sum of 'rolling_tempr' for group 36794046: 1323.23388972
# Sum of 'rolling_tempr' for group 36794048: 1420.502632938889
# Sum of 'rolling_tempr' for group 36794058: 1705.7109929255553
# Sum of 'rolling_tempr' for group 36794062: 1485.9201813722223
# Sum of 'rolling_tempr' for group 36794095: 1338.043326527778
# Sum of 'rolling_tempr' for group 36794298: 1731.1491334494444
# Sum of 'rolling_tempr' for group 36794406: 1640.9671100972223
# Sum of 'rolling_tempr' for group 36794443: 1640.9671100972223
# Sum of 'rolling_tempr' for group 36794498: 2466.3765568
# Sum of 'rolling_tempr' for group 36794572: 1845.0664654999998
# Sum of 'rolling_tempr' for group 36794625: 1285.3303697283332
# Sum of 'rolling_tempr' for group 36794645: 1797.0455555555554
# Sum of 'rolling_tempr' for group 36794716: 2494.1599249666665
# Sum of 'rolling_tempr' for group 36794892: 1634.6640485670002
# Sum of 'rolling_tempr' for group 36794895: 1775.9492613277775
# Sum of 'rolling_tempr' for group 36795041: 3386.5565530866666
# Sum of 'rolling_tempr' for group 36795045: 2306.7383733000006
# Sum of 'rolling_tempr' for group 36795582: 1876.7989362144442
# Sum of 'rolling_tempr' for group 36795607: 919.715139188889
# Sum of 'rolling_tempr' for group 36795624: 1034.51
# Sum of 'rolling_tempr' for group 36795637: 5139.1314917166665
# Sum of 'rolling_tempr' for group 36795675: 1376.8420406555556
# Sum of 'rolling_tempr' for group 36795745: 1031.637404708778
# Sum of 'rolling_tempr' for group 36795747: 1089.9352499166669
# Sum of 'rolling_tempr' for group 36795768: 987.4689375533334
# Sum of 'rolling_tempr' for group 36795826: 1283.8548432403704
# Sum of 'rolling_tempr' for group 36795919: 1063.871604397778
# Sum of 'rolling_tempr' for group 36796015: 3109.8680824722214
# Sum of 'rolling_tempr' for group 36796030: 2728.6618959333337
# Sum of 'rolling_tempr' for group 36796036: 1400.3661408166665
# Sum of 'rolling_tempr' for group 36796087: 1567.0556137166664
# Sum of 'rolling_tempr' for group 36796113: 1420.512632938889
# Sum of 'rolling_tempr' for group 36796169: 1382.6171357986668
# Sum of 'rolling_tempr' for group 36796176: 1399.4923775111113
# Sum of 'rolling_tempr' for group 36796182: 1338.0399931944446
# Sum of 'rolling_tempr' for group 36796225: 1395.4787608829631
# Sum of 'rolling_tempr' for group 36796347: 1705.7109929255553
# Sum of 'rolling_tempr' for group 36796409: 643.7255784111112
# Sum of 'rolling_tempr' for group 36796412: 1963.2781016644442
# Sum of 'rolling_tempr' for group 36796522: 1485.9201813722223
# Sum of 'rolling_tempr' for group 36796540: 3044.954485244444
# Sum of 'rolling_tempr' for group 36796555: 3113.619455811111
# Sum of 'rolling_tempr' for group 36796564: 1686.5918790011115
# Sum of 'rolling_tempr' for group 36796568: 3373.1837580022225
# Sum of 'rolling_tempr' for group 36796595: 1641.3704489555557
# Sum of 'rolling_tempr' for group 36796624: 1358.4597563333332
# Sum of 'rolling_tempr' for group 36796634: 9107.809227133333
# Sum of 'rolling_tempr' for group 36796653: 9024.013333333334
# Sum of 'rolling_tempr' for group 36797096: 1134.1246261500003
# Sum of 'rolling_tempr' for group 36797146: 1853.6963999555555
# Sum of 'rolling_tempr' for group 36797185: 1731.1491334494444
# Sum of 'rolling_tempr' for group 36797232: 1091.7627779850002
# Sum of 'rolling_tempr' for group 36797248: 1931.4324742588888
# Sum of 'rolling_tempr' for group 36797285: 1091.9265272138891
# Sum of 'rolling_tempr' for group 36797294: 1091.9265272138891
# Sum of 'rolling_tempr' for group 36797356: 679.2332115000002
# Sum of 'rolling_tempr' for group 36797500: 1808.2484659
# Sum of 'rolling_tempr' for group 36797521: 1563.8338212388887
# Sum of 'rolling_tempr' for group 36797525: 1914.6766477555557
# Sum of 'rolling_tempr' for group 36797593: 3195.7494289222223
# Sum of 'rolling_tempr' for group 36797596: 3195.7494289222223
# Sum of 'rolling_tempr' for group 36797599: 3195.7474414999997
# Sum of 'rolling_tempr' for group 36797634: 820.6852244777778
# Sum of 'rolling_tempr' for group 36797640: 1877.1308075922223
# Sum of 'rolling_tempr' for group 36797678: 799.5555555555557
# Sum of 'rolling_tempr' for group 36797716: 1191.5078600277775
# Sum of 'rolling_tempr' for group 36797777: 345.63410038722225
# Sum of 'rolling_tempr' for group 36797857: 1283.8548432403704
# Sum of 'rolling_tempr' for group 36797865: 0.0
# Sum of 'rolling_tempr' for group 36797866: 1089.9352499166669
# Sum of 'rolling_tempr' for group 36797931: 0.0
# Sum of 'rolling_tempr' for group 36797979: 1213.5672512988858
# Sum of 'rolling_tempr' for group 36797996: 1312.1966319166665
# Sum of 'rolling_tempr' for group 36798002: 1336.5499652499998
# Sum of 'rolling_tempr' for group 36798018: 1063.871604397778
# Sum of 'rolling_tempr' for group 36798021: 957.3383238777778
# Sum of 'rolling_tempr' for group 38193152: 0.0
# Sum of 'rolling_tempr' for group 38193347: 1018.4833333333332
# Sum of 'rolling_tempr' for group 38193352: 1555.21197966
# Sum of 'rolling_tempr' for group 38193360: 1981.9403399
# Sum of 'rolling_tempr' for group 38193886: 1730.5855345666666
# Sum of 'rolling_tempr' for group 38193914: 1260.5846156533335
# Sum of 'rolling_tempr' for group 38193924: 1134.1146261500003
# Sum of 'rolling_tempr' for group 38194073: 0.0
# Sum of 'rolling_tempr' for group 38194082: 0.0
# Sum of 'rolling_tempr' for group 38194200: 0.0
# Sum of 'rolling_tempr' for group 38194252: 1451.8125877833336
# Sum of 'rolling_tempr' for group 38194323: 1496.6658752800001
# Sum of 'rolling_tempr' for group 38194501: 1555.2053129933333
# Sum of 'rolling_tempr' for group 38194517: 1336.5499652499998
# Sum of 'rolling_tempr' for group 38194775: 1319.065534732222
# Sum of 'rolling_tempr' for group 38194782: 1605.041210467667
# Sum of 'rolling_tempr' for group 38194797: 1639.6612054190475
# Sum of 'rolling_tempr' for group 38194798: 1730.5855345666666
# Sum of 'rolling_tempr' for group 38194804: 1808.2484659
# Sum of 'rolling_tempr' for group 38194809: 1645.3925219200003
# Sum of 'rolling_tempr' for group 38195039: 0.0
# Sum of 'rolling_tempr' for group 38195055: 0.0
# Sum of 'rolling_tempr' for group 38195142: 542.7361133333333
# Sum of 'rolling_tempr' for group 38195176: 1213.5639179655525
# Sum of 'rolling_tempr' for group 38195270: 1285.3141843133335
# Sum of 'rolling_tempr' for group 38195322: 2000.0569960733333
# Sum of 'rolling_tempr' for group 38195517: 1971.0188964899999
# Sum of 'rolling_tempr' for group 38195528: 1254.385180424667
# Sum of 'rolling_tempr' for group 38195737: 3810.4567916
# Sum of 'rolling_tempr' for group 38196272: 2012.3453294066667
# Sum of 'rolling_tempr' for group 38196435: 1853.3295193333333
# Sum of 'rolling_tempr' for group 38196518: 1140.6745236666668
# Sum of 'rolling_tempr' for group 38196591: 1665.8249110833333
# Sum of 'rolling_tempr' for group 38196593: 1653.8753974799997
# Sum of 'rolling_tempr' for group 38196596: 1642.0369390833334
# Sum of 'rolling_tempr' for group 184961268: 1319.065534732222
# Sum of 'rolling_tempr' for group 184961304: 1022.2741425872218
# Sum of 'rolling_tempr' for group 184961316: 2137.4269228877774
# Sum of 'rolling_tempr' for group 184961436: 1117.7424736222222
# Sum of 'rolling_tempr' for group 185342652: 889.3677466166666
# Sum of 'rolling_tempr' for group 185342655: 958.2742178722223
# Sum of 'rolling_tempr' for group 185342696: 1030.844461411111
# Sum of 'rolling_tempr' for group 185724123: 1173.632319777778
# Sum of 'rolling_tempr' for group 193245095: 603.8349999999998
# Sum of 'rolling_tempr' for group 193245726: 1013.7109303722225
# Sum of 'rolling_tempr' for group 193246940: 926.5343454277778
# Sum of 'rolling_tempr' for group 193247058: 1100.2134421166666
# Sum of 'rolling_tempr' for group 193247111: 1098.1924328777777
# Sum of 'rolling_tempr' for group 193247335: 898.3899354111112
# Sum of 'rolling_tempr' for group 193247339: 982.6179770777778
# Sum of 'rolling_tempr' for group 193247370: 913.26948055
# Sum of 'rolling_tempr' for group 193247397: 967.4752586222221
# Sum of 'rolling_tempr' for group 193247410: 1123.251556392778
# Sum of 'rolling_tempr' for group 193248175: 265.22333333333336
# Sum of 'rolling_tempr' for group 193248178: 0.0
# Sum of 'rolling_tempr' for group 193249104: 744.5136158984849
# Sum of 'rolling_tempr' for group 193249398: 725.793697356818
# Sum of 'rolling_tempr' for group 193250743: 0.0
# Sum of 'rolling_tempr' for group 193250749: 881.8959044455555
# Sum of 'rolling_tempr' for group 193250764: 0.0
# Sum of 'rolling_tempr' for group 193250773: 1275.7030839000001
# Sum of 'rolling_tempr' for group 193250844: 1117.7424736222222
# Sum of 'rolling_tempr' for group 193251079: 823.8075698344445
# Sum of 'rolling_tempr' for group 193251165: 814.3888197
# Sum of 'rolling_tempr' for group 193252454: 863.9342518433333
# Sum of 'rolling_tempr' for group 193341756: 654.8198104166668
# Sum of 'rolling_tempr' for group 193342956: 345.63410038722225
# Sum of 'rolling_tempr' for group 193342964: 1089.9352499166669
# Sum of 'rolling_tempr' for group 193342965: 987.4689375533334
# Sum of 'rolling_tempr' for group 193342971: 1031.637404708778
# Sum of 'rolling_tempr' for group 193342972: 1031.637404708778
# Sum of 'rolling_tempr' for group 193343180: 799.5555555555557
# Sum of 'rolling_tempr' for group 193343181: 799.5555555555557
# Sum of 'rolling_tempr' for group 193343182: 799.5555555555557
# Sum of 'rolling_tempr' for group 193343211: 1260.5846156533335
# Sum of 'rolling_tempr' for group 193343226: 0.0
# Sum of 'rolling_tempr' for group 193343231: 0.0
# Sum of 'rolling_tempr' for group 193343238: 0.0
# Sum of 'rolling_tempr' for group 193343256: 1451.825921116667
# Sum of 'rolling_tempr' for group 193343270: 1581.1828616333332
# Sum of 'rolling_tempr' for group 193343271: 1496.6658752800001
# Sum of 'rolling_tempr' for group 193343301: 1842.4406927666669
# Sum of 'rolling_tempr' for group 193343314: 1910.6670065666667
# Sum of 'rolling_tempr' for group 193343328: 1645.0273386066665
# Sum of 'rolling_tempr' for group 193343330: 1735.4104743666667
# Sum of 'rolling_tempr' for group 193343345: 1018.4833333333332
# Sum of 'rolling_tempr' for group 193343355: 267.24333333333334
# Sum of 'rolling_tempr' for group 193343364: 0.0
# Sum of 'rolling_tempr' for group 193343365: 0.0
# Sum of 'rolling_tempr' for group 193343367: 0.0
# Sum of 'rolling_tempr' for group 193343382: 0.0
# Sum of 'rolling_tempr' for group 193343560: 1983.8605631566666
# Sum of 'rolling_tempr' for group 193343641: 1905.2283958
# Sum of 'rolling_tempr' for group 193343677: 1555.2932512555558
# Sum of 'rolling_tempr' for group 193343686: 1022.2741425872218
# Sum of 'rolling_tempr' for group 193343688: 998.3124924001664
# Sum of 'rolling_tempr' for group 193343872: 1640.26843334
# Sum of 'rolling_tempr' for group 193343886: 926.5476787611111
# Sum of 'rolling_tempr' for group 193343946: 898.3899354111112
# Sum of 'rolling_tempr' for group 193343964: 913.27948055
# Sum of 'rolling_tempr' for group 193343999: 716.1850292666667
# Sum of 'rolling_tempr' for group 193344039: 869.0633333333334
# Sum of 'rolling_tempr' for group 193344040: 615.0816666666667
# Sum of 'rolling_tempr' for group 193344065: 0.0
# Sum of 'rolling_tempr' for group 193344106: 1173.632319777778
# Sum of 'rolling_tempr' for group 193344113: 1079.5989572833334
# Sum of 'rolling_tempr' for group 193344426: 659.8017505535354
# Sum of 'rolling_tempr' for group 193345444: 1123.251556392778
# Sum of 'rolling_tempr' for group 193345858: 696.0563704238889
# Sum of 'rolling_tempr' for group 193346756: 0.0
# Sum of 'rolling_tempr' for group 193347022: 0.0
# Sum of 'rolling_tempr' for group 193347442: 1118.7138427094446
# Sum of 'rolling_tempr' for group 193348359: 854.7566211277777
# Sum of 'rolling_tempr' for group 193348379: 840.7585807588385
# Sum of 'rolling_tempr' for group 193349184: 854.4303833777776
# Sum of 'rolling_tempr' for group 193349745: 846.204405869697
# Sum of 'rolling_tempr' for group 193349781: 718.8600121333333
# Sum of 'rolling_tempr' for group 193349783: 718.8600121333333
# Sum of 'rolling_tempr' for group 193349790: 846.8400279909091
# Sum of 'rolling_tempr' for group 193349791: 846.8400279909091
# Sum of 'rolling_tempr' for group 193349799: 945.6930569333333
# Sum of 'rolling_tempr' for group 193350259: 725.7803640234847
# Sum of 'rolling_tempr' for group 193350263: 744.5136158984849
# Sum of 'rolling_tempr' for group 193350268: 507.7959715593939
# Sum of 'rolling_tempr' for group 193350269: 507.7959715593939
# Sum of 'rolling_tempr' for group 193350653: 710.9572284316666
# Sum of 'rolling_tempr' for group 193351735: 1044.1365785707071
# Sum of 'rolling_tempr' for group 193351737: 1046.4879119040402
# Sum of 'rolling_tempr' for group 193351849: 641.4895051000001
# Sum of 'rolling_tempr' for group 193352808: 881.8959044455555
# Sum of 'rolling_tempr' for group 193352811: 803.7634651666667
# Sum of 'rolling_tempr' for group 193352821: 871.0888979211112
# Sum of 'rolling_tempr' for group 193352827: 587.0457563707071
# Sum of 'rolling_tempr' for group 193352831: 890.5691815031333
# Sum of 'rolling_tempr' for group 193352832: 890.5691815031333
# Sum of 'rolling_tempr' for group 193353128: 814.3888197
# Sum of 'rolling_tempr' for group 193353130: 1105.3601472
# Sum of 'rolling_tempr' for group 193353254: 659.8017505535354
# Sum of 'rolling_tempr' for group 193353301: 888.8182251000001
# Sum of 'rolling_tempr' for group 193354675: 783.6053486212121
# Sum of 'rolling_tempr' for group 193354683: 765.5970202020203
# Sum of 'rolling_tempr' for group 193354896: 854.7566211277777
# Sum of 'rolling_tempr' for group 193354900: 658.9256654050001
# Sum of 'rolling_tempr' for group 194267099: 840.7585807588385
# Sum of 'rolling_tempr' for group 194267107: 774.5386729497981
# Sum of 'rolling_tempr' for group 194267109: 774.5386729497981
# Sum of 'rolling_tempr' for group 194267112: 424.6425755454545
# Sum of 'rolling_tempr' for group 194267117: 762.4065151515151
# Sum of 'rolling_tempr' for group 194268593: 748.7245915600001
# Sum of 'rolling_tempr' for group 194268596: 415.91490101666665
# Sum of 'rolling_tempr' for group 194268599: 831.7009283433333
# Sum of 'rolling_tempr' for group 194268601: 1002.369844311111
# Sum of 'rolling_tempr' for group 194269103: 820.3340415333333
# Sum of 'rolling_tempr' for group 194269104: 820.3340415333333
# Sum of 'rolling_tempr' for group 194269560: 661.3181522833335
# Sum of 'rolling_tempr' for group 194271167: 641.4895051000001
# Sum of 'rolling_tempr' for group 194271171: 831.7009283433333
# Sum of 'rolling_tempr' for group 194271964: 814.8128430466667
# Sum of 'rolling_tempr' for group 194271966: 814.8128430466667
# Sum of 'rolling_tempr' for group 194272529: 748.7245915600001
# Sum of 'rolling_tempr' for group 194272537: 1002.369844311111
# Sum of 'rolling_tempr' for group 194272651: 415.91490101666665
# Sum of 'rolling_tempr' for group 194272653: 415.91490101666665
# Sum of 'rolling_tempr' for group 194272664: 986.8426031833333
# Sum of 'rolling_tempr' for group 194272666: 986.8226031833333
# Sum of 'rolling_tempr' for group 194272763: 823.1523868355555
# Sum of 'rolling_tempr' for group 194272765: 823.1657201688888
# Sum of 'rolling_tempr' for group 194273307: 871.0722312544445
# Sum of 'rolling_tempr' for group 194273732: 871.0722312544445
# Sum of 'rolling_tempr' for group 194273733: 257.9170826594444
# Sum of 'rolling_tempr' for group 194273735: 257.9170826594444
# Sum of 'rolling_tempr' for group 194344032: 1141.484322472222
# Sum of 'rolling_tempr' for group 194345951: 1236.382037922222
# Sum of 'rolling_tempr' for group 194346735: 1482.7588038666665
# Sum of 'rolling_tempr' for group 194346740: 1552.8032959000002
# Sum of 'rolling_tempr' for group 194347372: 1193.3355555555554
# Sum of 'rolling_tempr' for group 194347373: 1193.332222222222
# Sum of 'rolling_tempr' for group 194347375: 1236.382037922222
# Sum of 'rolling_tempr' for group 194347727: 1486.774515061111
# Sum of 'rolling_tempr' for group 194347729: 1295.3727857000001
# Sum of 'rolling_tempr' for group 194347730: 1591.59708266
# Sum of 'rolling_tempr' for group 194347913: 1621.1627458077778
# Sum of 'rolling_tempr' for group 194348193: 1139.892291022222
# Sum of 'rolling_tempr' for group 194348196: 1141.4809891388886
# Sum of 'rolling_tempr' for group 194348502: 1148.715904916667
# Sum of 'rolling_tempr' for group 194348505: 1291.4549080833333
# Sum of 'rolling_tempr' for group 194348506: 1291.4549080833333
# Sum of 'rolling_tempr' for group 194349231: 1200.7136818249999
# Sum of 'rolling_tempr' for group 194349232: 1200.7136818249999
# Sum of 'rolling_tempr' for group 194349234: 1200.7170151583332
# Sum of 'rolling_tempr' for group 194349240: 1148.7225715833335
# Sum of 'rolling_tempr' for group 194349765: 1220.5746922766673
# Sum of 'rolling_tempr' for group 194349771: 1325.7247153500002
# Sum of 'rolling_tempr' for group 194349953: 1220.5746922766673
# Sum of 'rolling_tempr' for group 194349960: 1172.6239407666667
# Sum of 'rolling_tempr' for group 194349961: 1172.6239407666667
# Sum of 'rolling_tempr' for group 194349967: 1325.7247153500002
# Sum of 'rolling_tempr' for group 194351015: 869.1636434938889
# Sum of 'rolling_tempr' for group 194351016: 869.1636434938889
# Sum of 'rolling_tempr' for group 194351035: 832.1452307022221
# Sum of 'rolling_tempr' for group 194351036: 832.1452307022221
# Sum of 'rolling_tempr' for group 194353045: 1550.9059705833333
# Sum of 'rolling_tempr' for group 194353056: 1594.0645840999998
# Sum of 'rolling_tempr' for group 194353351: 1498.3525665000002
# Sum of 'rolling_tempr' for group 194353997: 1635.1520637166668
# Sum of 'rolling_tempr' for group 194354042: 1613.57412935
# Sum of 'rolling_tempr' for group 194354090: 1515.2363606777778
# Sum of 'rolling_tempr' for group 194354702: 732.4802275233335
# Sum of 'rolling_tempr' for group 194354704: 646.0726490333334
# Sum of 'rolling_tempr' for group 194354935: 1316.2519229227776
# Sum of 'rolling_tempr' for group 194355016: 1316.2519229227776
# Sum of 'rolling_tempr' for group 194356158: 0.0
# Sum of 'rolling_tempr' for group 194357513: 899.46560442
# Sum of 'rolling_tempr' for group 194357516: 747.5635254733334
# Sum of 'rolling_tempr' for group 194359029: 701.1430000122222
# Sum of 'rolling_tempr' for group 194359032: 768.0595882266666
# Sum of 'rolling_tempr' for group 194359033: 822.2777620133335
# Sum of 'rolling_tempr' for group 194359922: 722.6218403133333
# Sum of 'rolling_tempr' for group 194359933: 646.0726490333334
# Sum of 'rolling_tempr' for group 194360106: 733.3610552733334
# Sum of 'rolling_tempr' for group 194360371: 592.9812298166667
# Sum of 'rolling_tempr' for group 194360605: 733.3610552733334
# Sum of 'rolling_tempr' for group 194360607: 733.3610552733334
# Sum of 'rolling_tempr' for group 194360612: 728.6997705666666
# Sum of 'rolling_tempr' for group 194361482: 822.6701679422224
# Sum of 'rolling_tempr' for group 194361493: 728.7031039
# Sum of 'rolling_tempr' for group 194361501: 732.4802275233335
# Sum of 'rolling_tempr' for group 194361502: 732.4802275233335
# Sum of 'rolling_tempr' for group 194361642: 649.9983523500001
# Sum of 'rolling_tempr' for group 194361643: 635.1766856833334
# Sum of 'rolling_tempr' for group 194361866: 678.2472365666666
# Sum of 'rolling_tempr' for group 194433894: 0.0
# Sum of 'rolling_tempr' for group 194433900: 0.0
# Sum of 'rolling_tempr' for group 194433902: 0.0
# Sum of 'rolling_tempr' for group 194434637: 747.5635254733334
# Sum of 'rolling_tempr' for group 194434874: 779.3921698166669
# Sum of 'rolling_tempr' for group 194434945: 779.3921698166669
# Sum of 'rolling_tempr' for group 194434951: 899.46560442
# Sum of 'rolling_tempr' for group 194435144: 747.5435254733333
# Sum of 'rolling_tempr' for group 194435412: 592.9812298166667
# Sum of 'rolling_tempr' for group 194436589: 603.8338964833334
# Sum of 'rolling_tempr' for group 194436591: 759.8508521500002
# Sum of 'rolling_tempr' for group 194436969: 735.2110232333334
# Sum of 'rolling_tempr' for group 194437160: 649.9983523500001
# Sum of 'rolling_tempr' for group 194437665: 822.6635012755557
# Sum of 'rolling_tempr' for group 194449283: 871.0013536466668
# Sum of 'rolling_tempr' for group 194449833: 701.1430000122222
# Sum of 'rolling_tempr' for group 194450577: 0.0
# Sum of 'rolling_tempr' for group 194463116: 1221.4607244677777
# Sum of 'rolling_tempr' for group 194464368: 1082.6901612888887
# Sum of 'rolling_tempr' for group 194465026: 735.2110232333334
# Sum of 'rolling_tempr' for group 194465030: 759.8508521500002
# Sum of 'rolling_tempr' for group 194465073: 1047.3653588142224
# Sum of 'rolling_tempr' for group 194465785: 677.7440958111113
# Sum of 'rolling_tempr' for group 194465801: 600.9805951666667
# Sum of 'rolling_tempr' for group 194466219: 678.2405699
# Sum of 'rolling_tempr' for group 194466898: 645.9383333333333
# Sum of 'rolling_tempr' for group 194467190: 671.5435992722221
# Sum of 'rolling_tempr' for group 194467246: 620.3252604555554
# Sum of 'rolling_tempr' for group 194468614: 1189.6244577555556
# Sum of 'rolling_tempr' for group 194470059: 1561.4219234766667
# Sum of 'rolling_tempr' for group 194470060: 989.617777777778
# Sum of 'rolling_tempr' for group 194470072: 1232.1959892711113
# Sum of 'rolling_tempr' for group 194470199: 1018.0239691977778
# Sum of 'rolling_tempr' for group 194470276: 1299.1800043722221
# Sum of 'rolling_tempr' for group 194470655: 1267.617819417778
# Sum of 'rolling_tempr' for group 194474303: 1087.6693237568888
# Sum of 'rolling_tempr' for group 194474314: 1279.7295945222222
# Sum of 'rolling_tempr' for group 194476181: 1016.4154962666667
# Sum of 'rolling_tempr' for group 194476759: 1248.6380037166668
# Sum of 'rolling_tempr' for group 194476760: 1554.7828462833334
# Sum of 'rolling_tempr' for group 194477632: 1123.3858713
# Sum of 'rolling_tempr' for group 194477642: 1248.6380037166668
# Sum of 'rolling_tempr' for group 194478668: 1011.5625029888889
# Sum of 'rolling_tempr' for group 194478707: 1220.6111922754444
# Sum of 'rolling_tempr' for group 194478714: 1302.1651448872224
# Sum of 'rolling_tempr' for group 194479136: 1353.021104566667
# Sum of 'rolling_tempr' for group 194479380: 1180.9210900044443
# Sum of 'rolling_tempr' for group 194479390: 1180.9210900044443
# Sum of 'rolling_tempr' for group 194479626: 992.3444444444445
# Sum of 'rolling_tempr' for group 194479795: 1267.617819417778
# Sum of 'rolling_tempr' for group 194479799: 118.70555555555555
# Sum of 'rolling_tempr' for group 194479802: 89.50832216666666
# Sum of 'rolling_tempr' for group 194480338: 1087.6693237568888
# Sum of 'rolling_tempr' for group 194480496: 1101.2582384822222
# Sum of 'rolling_tempr' for group 194480900: 1058.6201659
# Sum of 'rolling_tempr' for group 194484032: 1138.2676058500003
# Sum of 'rolling_tempr' for group 194484248: 861.9987781733334
# Sum of 'rolling_tempr' for group 194484979: 2034.8834992333332
# Sum of 'rolling_tempr' for group 194488317: 382.3978452633333
# Sum of 'rolling_tempr' for group 194490550: 0.0
# Sum of 'rolling_tempr' for group 194490551: 1220.1917001222223
# Sum of 'rolling_tempr' for group 194490553: 184.76999999999998
# Sum of 'rolling_tempr' for group 194490935: 1183.95519352
# Sum of 'rolling_tempr' for group 194491132: 1130.9729644000001
# Sum of 'rolling_tempr' for group 194491140: 1183.95519352
# Sum of 'rolling_tempr' for group 194491999: 1245.3197684166662
# Sum of 'rolling_tempr' for group 194492018: 1245.3431017499997
# Sum of 'rolling_tempr' for group 194492035: 1130.9562977333335
# Sum of 'rolling_tempr' for group 194492219: 1245.3431017499997
# Sum of 'rolling_tempr' for group 194492227: 2490.6862035
# Sum of 'rolling_tempr' for group 194492600: 1213.7088041333334
# Sum of 'rolling_tempr' for group 194492611: 1213.7088041333334
# Sum of 'rolling_tempr' for group 194492997: 1230.7417044333336
# Sum of 'rolling_tempr' for group 194493078: 1534.013716233333
# Sum of 'rolling_tempr' for group 194493087: 1230.7417044333336
# Sum of 'rolling_tempr' for group 194493089: 1237.1637162333332
# Sum of 'rolling_tempr' for group 194493096: 1237.1637162333332
# Sum of 'rolling_tempr' for group 194497158: 1160.1135475444446
# Sum of 'rolling_tempr' for group 194497229: 0.0
# Sum of 'rolling_tempr' for group 194497314: 1220.1650334555557
# Sum of 'rolling_tempr' for group 194497337: 1251.6960897888891
# Sum of 'rolling_tempr' for group 194497495: 1308.4262092111112
# Sum of 'rolling_tempr' for group 194497860: 142.26666666666668
# Sum of 'rolling_tempr' for group 194498023: 0.0
# Sum of 'rolling_tempr' for group 194498183: 0.0
# Sum of 'rolling_tempr' for group 194498399: 0.0
# Sum of 'rolling_tempr' for group 194499320: 1010.7681054666667
# Sum of 'rolling_tempr' for group 194499511: 468.4333333333334
# Sum of 'rolling_tempr' for group 194499513: 926.2136896111111
# Sum of 'rolling_tempr' for group 194499675: 401.59000000000003
# Sum of 'rolling_tempr' for group 194499819: 27.21
# Sum of 'rolling_tempr' for group 194499966: 0.0
# Sum of 'rolling_tempr' for group 194500001: 0.0
# Sum of 'rolling_tempr' for group 194500246: 0.0
# Sum of 'rolling_tempr' for group 194500267: 0.0
# Sum of 'rolling_tempr' for group 194500426: 1663.0847583666668
# Sum of 'rolling_tempr' for group 194500472: 1663.0847583666668
# Sum of 'rolling_tempr' for group 194500820: 1649.7645992555556
# Sum of 'rolling_tempr' for group 194500841: 1677.883951988889
# Sum of 'rolling_tempr' for group 194502851: 0.0
# Sum of 'rolling_tempr' for group 194502868: 0.0
# Sum of 'rolling_tempr' for group 194503105: 0.0
# Sum of 'rolling_tempr' for group 194503141: 0.0
# Sum of 'rolling_tempr' for group 194503163: 0.0
# Sum of 'rolling_tempr' for group 194503202: 0.0
# Sum of 'rolling_tempr' for group 194503258: 0.0
# Sum of 'rolling_tempr' for group 194503283: 0.0
# Sum of 'rolling_tempr' for group 194503422: 0.0
# Sum of 'rolling_tempr' for group 194503453: 838.0940185833333
# Sum of 'rolling_tempr' for group 194503458: 864.7533357511111
# Sum of 'rolling_tempr' for group 194505439: 0.0
# Sum of 'rolling_tempr' for group 194505545: 0.0
# Sum of 'rolling_tempr' for group 194505636: 0.0
# Sum of 'rolling_tempr' for group 194506862: 0.0
# Sum of 'rolling_tempr' for group 194506868: 736.3889754555556
# Sum of 'rolling_tempr' for group 194506882: 1001.523942138889
# Sum of 'rolling_tempr' for group 194507392: 0.0
# Sum of 'rolling_tempr' for group 194507405: 0.0
# Sum of 'rolling_tempr' for group 194507436: 0.0
# Sum of 'rolling_tempr' for group 194507662: 711.2215740333334
# Sum of 'rolling_tempr' for group 194508030: 1066.3646205472226
# Sum of 'rolling_tempr' for group 194508032: 1066.3612872138892
# Sum of 'rolling_tempr' for group 194508036: 1066.3646205472226
# Sum of 'rolling_tempr' for group 194508887: 1112.4432309500005
# Sum of 'rolling_tempr' for group 194508901: 1112.4432309500005
# Sum of 'rolling_tempr' for group 194508909: 1112.4398976166672
# Sum of 'rolling_tempr' for group 194509091: 785.4014294166667
# Sum of 'rolling_tempr' for group 194509092: 1159.9922222222226
# Sum of 'rolling_tempr' for group 194509099: 814.7752341944445
# Sum of 'rolling_tempr' for group 194509100: 1159.9922222222226
# Sum of 'rolling_tempr' for group 194509273: 769.6086199722223
# Sum of 'rolling_tempr' for group 194509281: 785.3747627500001
# Sum of 'rolling_tempr' for group 194511735: 152.885
# Sum of 'rolling_tempr' for group 194511792: 1022.9422597555556
# Sum of 'rolling_tempr' for group 194511793: 1001.523942138889
# Sum of 'rolling_tempr' for group 194511795: 1022.9422597555556
# Sum of 'rolling_tempr' for group 194511802: 736.3889754555556
# Sum of 'rolling_tempr' for group 194511811: 1001.5172754722223
# Sum of 'rolling_tempr' for group 194511975: 0.0
# Sum of 'rolling_tempr' for group 194511978: 0.0
# Sum of 'rolling_tempr' for group 194512009: 0.0
# Sum of 'rolling_tempr' for group 194512011: 0.0
# Sum of 'rolling_tempr' for group 194512049: 0.0
# Sum of 'rolling_tempr' for group 194512132: 0.0
# Sum of 'rolling_tempr' for group 194512141: 0.0
# Sum of 'rolling_tempr' for group 194512147: 0.0
# Sum of 'rolling_tempr' for group 194512165: 0.0
# Sum of 'rolling_tempr' for group 194514338: 0.0
# Sum of 'rolling_tempr' for group 194514577: 0.0
# Sum of 'rolling_tempr' for group 194514863: 1073.508761666667
# Sum of 'rolling_tempr' for group 194520614: 94.87333333333333
# Sum of 'rolling_tempr' for group 194520628: 108.455
# Sum of 'rolling_tempr' for group 194520703: 1355.3145829277776
# Sum of 'rolling_tempr' for group 194520900: 1329.4441877
# Sum of 'rolling_tempr' for group 194520910: 1329.4441877
# Sum of 'rolling_tempr' for group 194521121: 1404.4537266833333
# Sum of 'rolling_tempr' for group 194521123: 1086.9930747166666
# Sum of 'rolling_tempr' for group 194521282: 1404.45039335
# Sum of 'rolling_tempr' for group 194521298: 1369.7495240000003
# Sum of 'rolling_tempr' for group 194521582: 1307.3837174633336
# Sum of 'rolling_tempr' for group 194521595: 1360.477857333333
# Sum of 'rolling_tempr' for group 194522560: 617.8850000000002
# Sum of 'rolling_tempr' for group 194522593: 515.1333333333333
# Sum of 'rolling_tempr' for group 194522737: 1359.6243870666672
# Sum of 'rolling_tempr' for group 194522846: 1351.9293498333332
# Sum of 'rolling_tempr' for group 194522929: 1372.9283906833334
# Sum of 'rolling_tempr' for group 194522932: 1342.0715527166667
# Sum of 'rolling_tempr' for group 194523087: 1342.0682193833334
# Sum of 'rolling_tempr' for group 194523088: 1405.9534223
# Sum of 'rolling_tempr' for group 194523187: 1428.3544437666667
# Sum of 'rolling_tempr' for group 194523331: 1461.7078523500002
# Sum of 'rolling_tempr' for group 194523335: 1428.3444437666667
# Sum of 'rolling_tempr' for group 194523351: 1476.174615433333
# Sum of 'rolling_tempr' for group 194527111: 1192.135578911111
# Sum of 'rolling_tempr' for group 194527254: 486.31227284111105
# Sum of 'rolling_tempr' for group 194527264: 630.5916093788888
# Sum of 'rolling_tempr' for group 194528576: 1273.780770975

# %%
df_smolt_data = df_smolt_data.merge(pd.DataFrame({'from_locus_population_id': list(sums_by_id.keys()), 'rolling_tempr_sum': list(sums_by_id.values())}), on='from_locus_population_id', how='left')

# %%
df_smolt_data
# Out:
#       locus_id  fish_group_id  transfer_year  transfer_month  \
# 0      3046036             11           2017               1
# 1      3046036           1052           2019               1
# 2      3046036           3918           2020              11
# 3      3046043            310           2017               6
# 4      3046043            498           2019               7
# ...        ...            ...            ...             ...
# 1086   7183889           6071           2022               6
# 1087   7183890           6072           2022               6
# 1088   7183891           6072           2022               6
# 1089   7183892           6069           2022               6
# 1090   7183893           6069           2022               6
#
#      transfer_month_year transfer_season  total_count total_mortality_perc_90  \
# 0                 1_2017          winter    44934,175             0,007496165
# 1                 1_2019          winter  46388,23077             0,003942904
# 2                11_2020          autumn  45241,16667             0,007676062
# 3                 6_2017          summer  38451,42593             0,018393697
# 4                 7_2019          summer  41131,79661             0,027013536
# ...                  ...             ...          ...                     ...
# 1086              6_2022          summer  44747,76389             0,012812974
# 1087              6_2022          summer  44563,77612             0,014813398
# 1088              6_2022          summer  44585,79167              0,01465357
# 1089              6_2022          summer  44244,95833             0,022575856
# 1090              6_2022          summer  43669,97015             0,035173785
#
#      transport_mortality_perc_90 nontransport_mortality_perc_90  ...  \
# 0                    0,001309054                    0,006187111  ...
# 1                    0,000924979                    0,003017925  ...
# 2                    0,005640632                    0,002035429  ...
# 3                    0,006842934                    0,011550763  ...
# 4                    0,022782874                    0,004230661  ...
# ...                          ...                            ...  ...
# 1086                 0,002758736                    0,010054239  ...
# 1087                 0,008025966                    0,006787432  ...
# 1088                 0,007419565                    0,007234005  ...
# 1089                 0,015284297                    0,007291559  ...
# 1090                 0,028200436                    0,006973349  ...
#
#               SGR          TGC  order_of_creation_from  strain  year_class  \
# 0             NaN          NaN                       6     FAN          16
# 1     0,863440282  0,951440321                       5     FLY          18
# 2     0,972984604  1,181745984                      11     FLY          19
# 3             NaN          NaN                      10     FLY          16
# 4     0,800972852  0,883692915                       3     LCY          18
# ...           ...          ...                     ...     ...         ...
# 1086  0,692506163  0,768343162                       3     FLY          21
# 1087  0,862384041  0,958244367                       3     FLY          21
# 1088  0,695116331  0,801179534                       3     FLY          21
# 1089   0,79240455   0,87628003                       3     FLY          21
# 1090  0,874297558   1,00176444                       3     FLY          21
#
#       number_of_prod_cycle place_first_feeding  specific_treatment  \
# 0                       C1                  PH                None
# 1                      C1B                  PH                None
# 2                       C4                  PH                 LUF
# 3                      C2B                  PH                None
# 4                       C3                 PGR                None
# ...                    ...                 ...                 ...
# 1086                    C2                  PH                 LUF
# 1087                    C2                  PH                 LUF
# 1088                    C2                  PH                 LUF
# 1089                    C2                  PH                 LUF
# 1090                    C2                  PH                 LUF
#
#       two_place_of_first_feeding  rolling_tempr_sum
# 0                              0                NaN
# 1                              0         783.761800
# 2                              0         641.489505
# 3                              0                NaN
# 4                              1        2494.159925
# ...                          ...                ...
# 1086                           0        1073.508762
# 1087                           0           0.000000
# 1088                           0           0.000000
# 1089                           0        1001.523942
# 1090                           0        1022.942260
#
# [1091 rows x 62 columns]

# %%
zero_count = (df_smolt_data['rolling_tempr_sum'] == 0).sum()
nan_count = df_smolt_data['rolling_tempr_sum'].isna().sum()

print("Number of zeros: ", zero_count)
print("Number of NaN values: ", nan_count)
# Out:
# Number of zeros:  98
# Number of NaN values:  275

# %%
df_smolt_data = df_smolt_data[df_smolt_data['rolling_tempr_sum'] != 0]
df_smolt_data = df_smolt_data.dropna(subset=['rolling_tempr_sum'])
df_smolt_data = df_smolt_data.reset_index(drop=True)

# %%
df_smolt_data
# Out:
#      locus_id  fish_group_id  transfer_year  transfer_month  \
# 0     3046036           1052           2019               1
# 1     3046036           3918           2020              11
# 2     3046043            498           2019               7
# 3     3046052            847           2019               7
# 4     3046064            159           2019               4
# ..        ...            ...            ...             ...
# 713   7183882           6069           2022               6
# 714   7183884           6069           2022               6
# 715   7183889           6071           2022               6
# 716   7183892           6069           2022               6
# 717   7183893           6069           2022               6
#
#     transfer_month_year transfer_season  total_count total_mortality_perc_90  \
# 0                1_2019          winter  46388,23077             0,003942904
# 1               11_2020          autumn  45241,16667             0,007676062
# 2                7_2019          summer  41131,79661             0,027013536
# 3                7_2019          summer  41498,96364             0,018026932
# 4                4_2019          spring  74572,21053             0,011419796
# ..                  ...             ...          ...                     ...
# 713              6_2022          summer     44712,52             0,009888684
# 714              6_2022          summer  44261,21622              0,02236275
# 715              6_2022          summer  44747,76389             0,012812974
# 716              6_2022          summer  44244,95833             0,022575856
# 717              6_2022          summer  43669,97015             0,035173785
#
#     transport_mortality_perc_90 nontransport_mortality_perc_90  ...  \
# 0                   0,000924979                    0,003017925  ...
# 1                   0,005640632                    0,002035429  ...
# 2                   0,022782874                    0,004230661  ...
# 3                    0,01520579                    0,002821141  ...
# 4                   0,002201648                    0,009218148  ...
# ..                          ...                            ...  ...
# 713                 0,004718095                    0,005170589  ...
# 714                 0,014216011                    0,008146739  ...
# 715                 0,002758736                    0,010054239  ...
# 716                 0,015284297                    0,007291559  ...
# 717                 0,028200436                    0,006973349  ...
#
#              SGR          TGC  order_of_creation_from  strain  year_class  \
# 0    0,863440282  0,951440321                       5     FLY          18
# 1    0,972984604  1,181745984                      11     FLY          19
# 2    0,800972852  0,883692915                       3     LCY          18
# 3    1,041554869  1,163037416                       3     FLY          18
# 4    1,265268997  1,409250642                       7     FLY          18
# ..           ...          ...                     ...     ...         ...
# 713  0,968481654  1,115425012                       4     FLY          21
# 714   0,79240455   0,87628003                       3     FLY          21
# 715  0,692506163  0,768343162                       3     FLY          21
# 716   0,79240455   0,87628003                       3     FLY          21
# 717  0,874297558   1,00176444                       3     FLY          21
#
#      number_of_prod_cycle place_first_feeding  specific_treatment  \
# 0                     C1B                  PH                None
# 1                      C4                  PH                 LUF
# 2                      C3                 PGR                None
# 3                      C3                 PGR                None
# 4                     C2B                  PH                None
# ..                    ...                 ...                 ...
# 713                    C3                  PH                 LUF
# 714                    C2                  PH                 LUF
# 715                    C2                  PH                 LUF
# 716                    C2                  PH                 LUF
# 717                    C2                  PH                 LUF
#
#      two_place_of_first_feeding  rolling_tempr_sum
# 0                             0         783.761800
# 1                             0         641.489505
# 2                             1        2494.159925
# 3                             1        1233.198278
# 4                             0         813.066101
# ..                          ...                ...
# 713                           0         736.388975
# 714                           0        1001.523942
# 715                           0        1073.508762
# 716                           0        1001.523942
# 717                           0        1022.942260
#
# [718 rows x 62 columns]

# %%
#df_smolt_data.drop(['rolling_tempr_sum_x'], axis='columns', inplace=True)

# %%
len(df_smolt_data)
# Out:
# 718

# %%
df_smolt_data.columns
# Out:
# Index(['locus_id', 'fish_group_id', 'transfer_year', 'transfer_month',
#        'transfer_month_year', 'transfer_season', 'total_count',
#        'total_mortality_perc_90', 'transport_mortality_perc_90',
#        'nontransport_mortality_perc_90', 'from_date', 'from_site_name',
#        'from_site_id', 'from_locus_id', 'from_locus_population_id',
#        'from_fish_group_id', 'from_fish_group_name', 'from_generation',
#        'from_year_class', 'from_count_stocking', 'from_avg_weight', 'to_date',
#        'type_id', 'to_site_name', 'to_site_id', 'to_locus_id',
#        'to_locus_population_id', 'to_fish_group_id', 'to_fish_group_name',
#        'to_generation', 'to_year_class', 'to_count_stocking', 'to_avg_weight',
#        'transfer_date', 'from_fish_group_count', 'days_btw_to_from',
#        'days_btw_to_transfer', 'vac_fish_count', 'vac_weight',
#        'days_btw_conf_event', '00000000000SRSv/Pha ', '000IPN+AAA+VVV+ISA/Pha',
#        'IPN+SRS+VIB+ASA+ISA/FAV', 'IPN+SRS+VVV+AAA+ISA/Pha',
#        'IPN+SRS+VVV+ISA/Fav   ', 'IPN-SRS-VVV-AAA-ISA/Cvt',
#        'vaccine_manufacturer_CENTROVET', 'vaccine_manufacturer_FAV',
#        'vaccine_manufacturer_PHARMAQ', 'uta', 'days_btw_transfer_conf',
#        'date_conf', 'SGR', 'TGC', 'order_of_creation_from', 'strain',
#        'year_class', 'number_of_prod_cycle', 'place_first_feeding',
#        'specific_treatment', 'two_place_of_first_feeding',
#        'rolling_tempr_sum'],
#       dtype='object')

# %% [markdown]
# # SGR

# %%
df_smolt_data['SGR'] = df_smolt_data['SGR'].str.replace(',', '.')

df_smolt_data['SGR'] = df_smolt_data['SGR'].astype(float)

# %%
df_smolt_data['total_mortality_perc_90'] = df_smolt_data['total_mortality_perc_90'].str.replace(',', '.')

df_smolt_data['total_mortality_perc_90'] = df_smolt_data['total_mortality_perc_90'].astype(float)

# %%
correlation = df_smolt_data['SGR'].corr(df_smolt_data['total_mortality_perc_90'])

print("Correlation between SGR and total_mortality_perc_90:", correlation)
# Out:
# Correlation between SGR and total_mortality_perc_90: -0.07611045027548537

# %%
df_smolt_data = df_smolt_data.dropna(subset=['SGR'])

df_smolt_data = df_smolt_data.reset_index(drop=True)

# %%
median_sgr = df_smolt_data['SGR'].median()


df_smolt_data['group'] = np.where(df_smolt_data['SGR'] < median_sgr, 0, 1)

# %%
df_smolt_data
# Out:
#      locus_id  fish_group_id  transfer_year  transfer_month  \
# 0     3046036           1052           2019               1
# 1     3046036           3918           2020              11
# 2     3046043            498           2019               7
# 3     3046052            847           2019               7
# 4     3046064            159           2019               4
# ..        ...            ...            ...             ...
# 713   7183882           6069           2022               6
# 714   7183884           6069           2022               6
# 715   7183889           6071           2022               6
# 716   7183892           6069           2022               6
# 717   7183893           6069           2022               6
#
#     transfer_month_year transfer_season  total_count  total_mortality_perc_90  \
# 0                1_2019          winter  46388,23077                 0.003943
# 1               11_2020          autumn  45241,16667                 0.007676
# 2                7_2019          summer  41131,79661                 0.027014
# 3                7_2019          summer  41498,96364                 0.018027
# 4                4_2019          spring  74572,21053                 0.011420
# ..                  ...             ...          ...                      ...
# 713              6_2022          summer     44712,52                 0.009889
# 714              6_2022          summer  44261,21622                 0.022363
# 715              6_2022          summer  44747,76389                 0.012813
# 716              6_2022          summer  44244,95833                 0.022576
# 717              6_2022          summer  43669,97015                 0.035174
#
#     transport_mortality_perc_90 nontransport_mortality_perc_90  ...  \
# 0                   0,000924979                    0,003017925  ...
# 1                   0,005640632                    0,002035429  ...
# 2                   0,022782874                    0,004230661  ...
# 3                    0,01520579                    0,002821141  ...
# 4                   0,002201648                    0,009218148  ...
# ..                          ...                            ...  ...
# 713                 0,004718095                    0,005170589  ...
# 714                 0,014216011                    0,008146739  ...
# 715                 0,002758736                    0,010054239  ...
# 716                 0,015284297                    0,007291559  ...
# 717                 0,028200436                    0,006973349  ...
#
#              TGC order_of_creation_from  strain  year_class  \
# 0    0,951440321                      5     FLY          18
# 1    1,181745984                     11     FLY          19
# 2    0,883692915                      3     LCY          18
# 3    1,163037416                      3     FLY          18
# 4    1,409250642                      7     FLY          18
# ..           ...                    ...     ...         ...
# 713  1,115425012                      4     FLY          21
# 714   0,87628003                      3     FLY          21
# 715  0,768343162                      3     FLY          21
# 716   0,87628003                      3     FLY          21
# 717   1,00176444                      3     FLY          21
#
#      number_of_prod_cycle  place_first_feeding specific_treatment  \
# 0                     C1B                   PH               None
# 1                      C4                   PH                LUF
# 2                      C3                  PGR               None
# 3                      C3                  PGR               None
# 4                     C2B                   PH               None
# ..                    ...                  ...                ...
# 713                    C3                   PH                LUF
# 714                    C2                   PH                LUF
# 715                    C2                   PH                LUF
# 716                    C2                   PH                LUF
# 717                    C2                   PH                LUF
#
#      two_place_of_first_feeding  rolling_tempr_sum  group
# 0                             0         783.761800      0
# 1                             0         641.489505      1
# 2                             1        2494.159925      0
# 3                             1        1233.198278      1
# 4                             0         813.066101      1
# ..                          ...                ...    ...
# 713                           0         736.388975      1
# 714                           0        1001.523942      0
# 715                           0        1073.508762      0
# 716                           0        1001.523942      0
# 717                           0        1022.942260      0
#
# [718 rows x 63 columns]

# %%
sns.scatterplot(data=df_smolt_data, x='total_mortality_perc_90', y='SGR', hue='group')
plt.show()

# %%
df_smolt_data['total_mortality_perc_90'] = pd.to_numeric(df_smolt_data['total_mortality_perc_90'], errors='coerce')

# %%
df_smolt_data
# Out:
#      locus_id  fish_group_id  transfer_year  transfer_month  \
# 0     3046036           1052           2019               1
# 1     3046036           3918           2020              11
# 2     3046043            498           2019               7
# 3     3046052            847           2019               7
# 4     3046064            159           2019               4
# ..        ...            ...            ...             ...
# 713   7183882           6069           2022               6
# 714   7183884           6069           2022               6
# 715   7183889           6071           2022               6
# 716   7183892           6069           2022               6
# 717   7183893           6069           2022               6
#
#     transfer_month_year transfer_season  total_count  total_mortality_perc_90  \
# 0                1_2019          winter  46388,23077                 0.003943
# 1               11_2020          autumn  45241,16667                 0.007676
# 2                7_2019          summer  41131,79661                 0.027014
# 3                7_2019          summer  41498,96364                 0.018027
# 4                4_2019          spring  74572,21053                 0.011420
# ..                  ...             ...          ...                      ...
# 713              6_2022          summer     44712,52                 0.009889
# 714              6_2022          summer  44261,21622                 0.022363
# 715              6_2022          summer  44747,76389                 0.012813
# 716              6_2022          summer  44244,95833                 0.022576
# 717              6_2022          summer  43669,97015                 0.035174
#
#     transport_mortality_perc_90 nontransport_mortality_perc_90  ...  \
# 0                   0,000924979                    0,003017925  ...
# 1                   0,005640632                    0,002035429  ...
# 2                   0,022782874                    0,004230661  ...
# 3                    0,01520579                    0,002821141  ...
# 4                   0,002201648                    0,009218148  ...
# ..                          ...                            ...  ...
# 713                 0,004718095                    0,005170589  ...
# 714                 0,014216011                    0,008146739  ...
# 715                 0,002758736                    0,010054239  ...
# 716                 0,015284297                    0,007291559  ...
# 717                 0,028200436                    0,006973349  ...
#
#              TGC order_of_creation_from  strain  year_class  \
# 0    0,951440321                      5     FLY          18
# 1    1,181745984                     11     FLY          19
# 2    0,883692915                      3     LCY          18
# 3    1,163037416                      3     FLY          18
# 4    1,409250642                      7     FLY          18
# ..           ...                    ...     ...         ...
# 713  1,115425012                      4     FLY          21
# 714   0,87628003                      3     FLY          21
# 715  0,768343162                      3     FLY          21
# 716   0,87628003                      3     FLY          21
# 717   1,00176444                      3     FLY          21
#
#      number_of_prod_cycle  place_first_feeding specific_treatment  \
# 0                     C1B                   PH               None
# 1                      C4                   PH                LUF
# 2                      C3                  PGR               None
# 3                      C3                  PGR               None
# 4                     C2B                   PH               None
# ..                    ...                  ...                ...
# 713                    C3                   PH                LUF
# 714                    C2                   PH                LUF
# 715                    C2                   PH                LUF
# 716                    C2                   PH                LUF
# 717                    C2                   PH                LUF
#
#      two_place_of_first_feeding  rolling_tempr_sum  group
# 0                             0         783.761800      0
# 1                             0         641.489505      1
# 2                             1        2494.159925      0
# 3                             1        1233.198278      1
# 4                             0         813.066101      1
# ..                          ...                ...    ...
# 713                           0         736.388975      1
# 714                           0        1001.523942      0
# 715                           0        1073.508762      0
# 716                           0        1001.523942      0
# 717                           0        1022.942260      0
#
# [718 rows x 63 columns]

# %%
group_0 = df_smolt_data[df_smolt_data['group'] == 0]['total_mortality_perc_90']
group_1 = df_smolt_data[df_smolt_data['group'] == 1]['total_mortality_perc_90']

sample_std = np.std(group_0, ddof=1) 

n = len(group_0)  
population_std = sample_std * np.sqrt(n / (n - 1))

# %%
sample_std
# Out:
# 0.013306602967795473

# %%
import statsmodels.api as sm
from statsmodels.stats.weightstats import ztest

group_0 = df_smolt_data[df_smolt_data['group'] == 0]['total_mortality_perc_90']
group_1 = df_smolt_data[df_smolt_data['group'] == 1]['total_mortality_perc_90']

population_std = 0.013306602967795473  

z_statistic, p_value = ztest(group_0, group_1, value=0, alternative='two-sided', usevar='pooled', ddof=0)

# Print the z-statistic and p-value
print("Z-Statistic: ", z_statistic)
print("P-Value: ", p_value)
# Out:
# Z-Statistic:  1.1383337679930507
# P-Value:  0.2549811387330352

# %%
Z-test failed and non valid due to distribution form
# Out:
#   File "<ipython-input-510-ec8b8be8399b>", line 1
#     Z-test failed and non valid due to distribution form
#            ^
# SyntaxError: invalid syntax

# %%
group_0 = df_smolt_data[df_smolt_data['group'] == 0]['total_mortality_perc_90']
#        0.00820253, 0.0139044 , 0.00489324, 0.00860846, 0.01368939,
#        0.00446111, 0.00886974, 0.01161372, 0.00465979, 0.03310284,
#        0.02874967, 0.00387391, 0.01123095, 0.02620281, 0.04518066,
#        0.00332117, 0.01808645, 0.00758318, 0.00577968, 0.0096009 ,
#        0.02630755, 0.00742907, 0.0066066 , 0.02992918, 0.00908011,
#        0.01086257, 0.02609481, 0.02824674, 0.00515933, 0.00633043,
#        0.00764649, 0.00529265, 0.03638969, 0.00932515, 0.00526959,
#        0.01922348, 0.00913041, 0.00668444, 0.00518273, 0.0144784 ,
#        0.00668774, 0.01511116, 0.03111346, 0.00495882, 0.02392336,
#        0.03866715, 0.008778  , 0.02792028, 0.04371887, 0.00753503,
#        0.01502915, 0.00373079, 0.01474903, 0.02290625, 0.00652069,
#        0.01067227, 0.00866782, 0.00728837, 0.01411704, 0.01683103,
#        0.00504605, 0.00456566, 0.00791909, 0.00517423, 0.00668829,
#        0.02033967, 0.00497155, 0.00974477, 0.00555437, 0.03747728,
#        0.0233531 , 0.02469199, 0.01073988, 0.07369065, 0.01355467,
#        0.00863569, 0.03544315, 0.01789753, 0.01104464, 0.00499928,
#        0.01160923, 0.01239769, 0.00849784, 0.00475445, 0.02295791,
#        0.00417943, 0.00405704, 0.00639435, 0.01684951, 0.01763025,
#        0.03817617, 0.0068651 , 0.01562486, 0.01095572, 0.01138894,
#        0.00988854, 0.04071707, 0.01359763, 0.01914173, 0.00785139,
#        0.00942796, 0.01314817, 0.01511137, 0.01069568, 0.01082471,
#        0.00803615, 0.00969004, 0.07074626, 0.05628399, 0.01247695,
#        0.06766256, 0.0184547 , 0.00863285, 0.01323124, 0.01132268,
#        0.0091538 , 0.0124292 , 0.01905793, 0.00319163, 0.00312055,
#        0.04986458, 0.00781501, 0.02754827, 0.00695622, 0.00361778,
#        0.01444034, 0.01051838, 0.0089242 , 0.03648915, 0.01415805,
#        0.00812642, 0.0230329 , 0.00774487, 0.01174866, 0.01543819,
#        0.0579612 , 0.04407737, 0.00411504, 0.01094504, 0.06850257,
#        0.00840365, 0.01322255, 0.02581453, 0.01190093, 0.00856399,
#        0.01553391, 0.00841781, 0.00973095, 0.00479257, 0.00947584,
#        0.01142554, 0.0051114 , 0.01269369, 0.00435335, 0.01063062,
#        0.00383503, 0.00683763, 0.00552429, 0.01167235, 0.00689079,
#        0.00497807, 0.01781693, 0.0051057 , 0.0077202 , 0.00708768,
#        0.00359174, 0.00160117, 0.00482179, 0.00954646, 0.03673806,
#        0.02031385, 0.05810447, 0.01542757, 0.01222394, 0.01608592,
#        0.02236275, 0.01281297, 0.02257586, 0.03517378])

# %%
group_0 = df_smolt_data[df_smolt_data['group'] == 0]['total_mortality_perc_90']
group_1 = df_smolt_data[df_smolt_data['group'] == 1]['total_mortality_perc_90']

# Run t-test
t_statistic, p_value = stats.ttest_ind(group_0, group_1)

# Print the t-statistic and p-value
print("T-Statistic: ", t_statistic)
print("P-Value: ", p_value)
# Out:
# T-Statistic:  1.1367472393224218
# P-Value:  0.25602426320398103

# %%
T-test failed and non valid due to distribution form
# Out:
#   File "<ipython-input-514-41ea2a82d2a0>", line 1
#     T-test failed and non valid due to distribution form
#            ^
# SyntaxError: invalid syntax

# %%
from scipy.stats import mannwhitneyu

group_0 = df_smolt_data[df_smolt_data['group'] == 0]['total_mortality_perc_90']
group_1 = df_smolt_data[df_smolt_data['group'] == 1]['total_mortality_perc_90']

statistic, p_value = mannwhitneyu(group_0, group_1, alternative='two-sided')

print("Mann-Whitney U statistic: ", statistic)
print("P-Value: ", p_value)
# Out:
# Mann-Whitney U statistic:  70121.0
# P-Value:  0.040953929796124264

# %%
mean_values = df_smolt_data.groupby('group')['total_mortality_perc_90'].mean()
median_values = df_smolt_data.groupby('group')['total_mortality_perc_90'].median()
#mode_values = df_smolt_data.groupby('group')['total_mortality_perc_90'].agg(pd.Series.mode)
min_values = df_smolt_data.groupby('group')['total_mortality_perc_90'].min()
max_values = df_smolt_data.groupby('group')['total_mortality_perc_90'].max()
# Print the results
print("Mean values:")
print(mean_values)
print("\nMedian values:")
print(median_values)
#print("\nMode values:")
#print(mode_values)
print("\nMinimum values:")
print(min_values)
print("\nMaximum values:")
print(max_values)
# Out:
# Mean values:
# group
# 0    0.015552
# 1    0.014418
# Name: total_mortality_perc_90, dtype: float64
#
# Median values:
# group
# 0    0.010956
# 1    0.009621
# Name: total_mortality_perc_90, dtype: float64
#
# Minimum values:
# group
# 0    0.001601
# 1    0.002496
# Name: total_mortality_perc_90, dtype: float64
#
# Maximum values:
# group
# 0    0.084519
# 1    0.090181
# Name: total_mortality_perc_90, dtype: float64

# %%
data0 = df_smolt_data[df_smolt_data['group'] == 0]['total_mortality_perc_90']
data1 = df_smolt_data[df_smolt_data['group'] == 1]['total_mortality_perc_90']
plt.hist(data0, bins=30, alpha=0.5, label='Data 0', density=True)
plt.hist(data1, bins=30, alpha=0.5, label='Data 1', density=True)

plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Distribution Comparison')
plt.legend()

plt.show()

# %%
data0 = df_smolt_data[df_smolt_data['group'] == 0]['total_mortality_perc_90']

# %%
sample_mean = data0.mean()
sample_std = data0.std()

# %%
sample_means0 = []
num_samples=3000
sample_size=30
for i in range(num_samples):
    sample = np.random.choice(data0, size=sample_size, replace=True)
    sample_means0.append(sample.mean())

# %%
plt.hist(sample_means0, bins=30, density=True, alpha=0.5)
plt.xlabel('Sample Mean')
plt.ylabel('Probability Density')
plt.title('Normal Distribution Approximation')
plt.show()

# %%
sample_means
# Out:
# [0.02398670770000001,
#  0.0117225527,
#  0.01567331456666667,
#  0.013273918599999998,
#  0.01605281223333333,
#  0.013774259800000003,
#  0.015894291366666664,
#  0.013446528499999999,
#  0.014162897266666667,
#  0.011615804733333335,
#  0.014756151166666667,
#  0.0148065626,
#  0.019479753666666662,
#  0.012891579900000002,
#  0.015823906000000002,
#  0.012426131499999998,
#  0.0141320188,
#  0.01316659786666667,
#  0.010195608333333335,
#  0.0170037828,
#  0.016370776433333335,
#  0.012106299166666666,
#  0.0159111679,
#  0.010770427700000001,
#  0.013469303566666669,
#  0.014587457233333333,
#  0.012615806100000003,
#  0.0161587708,
#  0.012351938466666665,
#  0.013461802900000002,
#  0.012789005366666665,
#  0.013784649566666668,
#  0.012743881866666668,
#  0.018480654866666665,
#  0.0105008111,
#  0.015151589066666667,
#  0.0160691952,
#  0.01427897106666667,
#  0.010739625966666666,
#  0.016496697500000004,
#  0.01353423693333333,
#  0.012342654833333333,
#  0.013209408266666667,
#  0.021241637066666666,
#  0.013770760666666666,
#  0.013896366633333334,
#  0.017127420566666666,
#  0.012977735833333334,
#  0.0159322766,
#  0.011521717233333334,
#  0.012630887866666666,
#  0.01718562276666667,
#  0.013061780700000001,
#  0.014701689033333335,
#  0.01603122016666667,
#  0.0160801891,
#  0.012309388100000002,
#  0.014018091066666665,
#  0.013463604999999998,
#  0.014003641366666668,
#  0.010855184033333335,
#  0.012224477066666666,
#  0.013221506800000001,
#  0.01344940426666667,
#  0.012129615533333332,
#  0.014819865866666669,
#  0.015682450533333333,
#  0.012595148000000002,
#  0.015342333833333334,
#  0.017619481233333335,
#  0.012759256266666666,
#  0.015539700466666665,
#  0.017264597533333335,
#  0.011143468699999999,
#  0.013539821633333334,
#  0.01563424633333333,
#  0.0140030054,
#  0.01286632903333333,
#  0.0140027131,
#  0.018214842233333337,
#  0.0141001202,
#  0.0148889551,
#  0.015879578966666665,
#  0.013283920100000004,
#  0.017037479,
#  0.012244090166666667,
#  ...]

# %%
data1 = df_smolt_data[df_smolt_data['group'] == 1]['total_mortality_perc_90']

# %%
sample_mean = data1.mean()
sample_std = data1.std()

# %%
sample_means1 = []
num_samples=3000
sample_size=30
for i in range(num_samples):
    sample = np.random.choice(data1, size=sample_size, replace=True)
    sample_means1.append(sample.mean())

# %%
plt.hist(sample_means1, bins=30, density=True, alpha=0.5)
plt.xlabel('Sample Mean')
plt.ylabel('Probability Density')
plt.title('Normal Distribution Approximation')
plt.show()

# %%
plt.hist(sample_means0, bins=30, alpha=0.5, label='Data 0', density=True)
plt.hist(sample_means1, bins=30, alpha=0.5, label='Data 1', density=True)

plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Distribution Comparison')
plt.legend()

plt.show()

# %%
data0
# Out:
# 0      0.003943
# 2      0.027014
# 5      0.018263
# 7      0.010291
# 12     0.030168
#          ...
# 711    0.016086
# 714    0.022363
# 715    0.012813
# 716    0.022576
# 717    0.035174
# Name: total_mortality_perc_90, Length: 359, dtype: float64

# %%
group_0 = sample_means0
group_1 = sample_means1

# Run t-test
t_statistic, p_value = stats.ttest_ind(group_0, group_1)

# Print the t-statistic and p-value
print("T-Statistic: ", t_statistic)
print("P-Value: ", p_value)
# Out:
# T-Statistic:  16.94612739975623
# P-Value:  5.886544337452842e-63

# %% [markdown]
# # SGR filtered

# %%
sorted_df = df_smolt_data.sort_values('rolling_tempr_sum')
exclude_rows = int(len(sorted_df) * 0.25)
filtered_df = sorted_df.iloc[exclude_rows:-exclude_rows]
filtered_df = filtered_df.reset_index(drop=True)

# %%
df_smolt_data=filtered_df

# %%
df_smolt_data['SGR'] = df_smolt_data['SGR'].str.replace(',', '.')

df_smolt_data['SGR'] = df_smolt_data['SGR'].astype(float)

# %%
df_smolt_data['total_mortality_perc_90'] = df_smolt_data['total_mortality_perc_90'].str.replace(',', '.')

df_smolt_data['total_mortality_perc_90'] = df_smolt_data['total_mortality_perc_90'].astype(float)

# %%
correlation = df_smolt_data['SGR'].corr(df_smolt_data['total_mortality_perc_90'])

print("Correlation between SGR and total_mortality_perc_90:", correlation)
# Out:
# Correlation between SGR and total_mortality_perc_90: 0.020327075020659027

# %%
df_smolt_data = df_smolt_data.dropna(subset=['SGR'])

df_smolt_data = df_smolt_data.reset_index(drop=True)

# %%
median_sgr = df_smolt_data['SGR'].median()


df_smolt_data['group'] = np.where(df_smolt_data['SGR'] < median_sgr, 0, 1)

# %%
sns.scatterplot(data=df_smolt_data, x='total_mortality_perc_90', y='SGR', hue='group')
plt.show()

# %%
group_0 = df_smolt_data[df_smolt_data['group'] == 0]['total_mortality_perc_90']
group_1 = df_smolt_data[df_smolt_data['group'] == 1]['total_mortality_perc_90']

statistic, p_value = mannwhitneyu(group_0, group_1, alternative='two-sided')

print("Mann-Whitney U statistic: ", statistic)
print("P-Value: ", p_value)
# Out:
# Mann-Whitney U statistic:  16241.0
# P-Value:  0.9672781530968443

# %%
mean_values = df_smolt_data.groupby('group')['total_mortality_perc_90'].mean()
median_values = df_smolt_data.groupby('group')['total_mortality_perc_90'].median()
#mode_values = df_smolt_data.groupby('group')['total_mortality_perc_90'].agg(pd.Series.mode)
min_values = df_smolt_data.groupby('group')['total_mortality_perc_90'].min()
max_values = df_smolt_data.groupby('group')['total_mortality_perc_90'].max()
# Print the results
print("Mean values:")
print(mean_values)
print("\nMedian values:")
print(median_values)
#print("\nMode values:")
#print(mode_values)
print("\nMinimum values:")
print(min_values)
print("\nMaximum values:")
print(max_values)
# Out:
# Mean values:
# group
# 0    0.013445
# 1    0.013663
# Name: total_mortality_perc_90, dtype: float64
#
# Median values:
# group
# 0    0.009200
# 1    0.009236
# Name: total_mortality_perc_90, dtype: float64
#
# Minimum values:
# group
# 0    0.001601
# 1    0.002496
# Name: total_mortality_perc_90, dtype: float64
#
# Maximum values:
# group
# 0    0.070746
# 1    0.079301
# Name: total_mortality_perc_90, dtype: float64

# %% [markdown]
# # SGR + Sampling

# %%
from scipy.stats import mannwhitneyu

# %%
df_smolt_data['SGR'] = df_smolt_data['SGR'].str.replace(',', '.')

df_smolt_data['SGR'] = df_smolt_data['SGR'].astype(float)

# %%
df_smolt_data['total_mortality_perc_90'] = df_smolt_data['total_mortality_perc_90'].str.replace(',', '.')

df_smolt_data['total_mortality_perc_90'] = df_smolt_data['total_mortality_perc_90'].astype(float)
correlation = df_smolt_data['SGR'].corr(df_smolt_data['total_mortality_perc_90'])

print("Correlation between SGR and total_mortality_perc_90:", correlation)
# Out:
# Correlation between SGR and total_mortality_perc_90: -0.07611045027548537

# %%
df_smolt_data = df_smolt_data.dropna(subset=['SGR'])
df_smolt_data = df_smolt_data.reset_index(drop=True)
median_sgr = df_smolt_data['SGR'].median()
df_smolt_data['group'] = np.where(df_smolt_data['SGR'] < median_sgr, 0, 1)
df_smolt_data['total_mortality_perc_90'] = pd.to_numeric(df_smolt_data['total_mortality_perc_90'], errors='coerce')

# %%
data1 = df_smolt_data[df_smolt_data['group'] == 1]['total_mortality_perc_90']
data0 = df_smolt_data[df_smolt_data['group'] == 0]['total_mortality_perc_90']

# %%
sample_mean = data1.mean()
sample_std = data1.std()

# %%
num_samples=5000
sample_size=20
p_values=[]
u_stats=[]
for i in range(num_samples):
    sample0 = np.random.choice(data0, size=sample_size, replace=True)
    sample1 = np.random.choice(data1, size=sample_size, replace=True)
    statistic, p_value = mannwhitneyu(sample0, sample1, alternative='two-sided')
    p_values.append(p_value)
    u_stats.append(statistic)
    #print("Mann-Whitney U statistic: ", statistic)
    #print("P-Value: ", p_value)

# %%
plt.hist(u_stats, alpha=0.5, density=True)
# Out:
# (array([8.49420849e-05, 3.62934363e-04, 1.79922780e-03, 4.79536680e-03,
#         8.59459459e-03, 1.02625483e-02, 7.86100386e-03, 3.84555985e-03,
#         8.57142857e-04, 1.46718147e-04]),
#  array([ 80. , 105.9, 131.8, 157.7, 183.6, 209.5, 235.4, 261.3, 287.2,
#         313.1, 339. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(u_stats, bins=30, density=True, alpha=0.5)
# Out:
# (array([2.33463035e-05, 7.00389105e-05, 4.66926070e-05, 4.66926070e-05,
#         3.03501946e-04, 6.07003891e-04, 9.33852140e-04, 1.72762646e-03,
#         2.70817121e-03, 3.71206226e-03, 4.97276265e-03, 6.32684825e-03,
#         8.77821012e-03, 9.08171206e-03, 1.06459144e-02, 1.14163424e-02,
#         1.04357977e-02, 1.01789883e-02, 8.66147860e-03, 8.26459144e-03,
#         5.01945525e-03, 4.87937743e-03, 3.12840467e-03, 2.03112840e-03,
#         1.35408560e-03, 6.07003891e-04, 3.96887160e-04, 1.63424125e-04,
#         1.63424125e-04, 4.66926070e-05]),
#  array([ 83.        ,  91.56666667, 100.13333333, 108.7       ,
#         117.26666667, 125.83333333, 134.4       , 142.96666667,
#         151.53333333, 160.1       , 168.66666667, 177.23333333,
#         185.8       , 194.36666667, 202.93333333, 211.5       ,
#         220.06666667, 228.63333333, 237.2       , 245.76666667,
#         254.33333333, 262.9       , 271.46666667, 280.03333333,
#         288.6       , 297.16666667, 305.73333333, 314.3       ,
#         322.86666667, 331.43333333, 340.        ]),
#  <a list of 30 Patch objects>)

# %%
plt.hist(p_values, alpha=0.5, density=True)
# Out:
# (array([1.46608342, 1.15668927, 1.01918075, 1.07782409, 0.97873707,
#         0.7846074 , 0.85942821, 0.81898453, 0.92211592, 1.02726949]),
#  array([1.79238233e-04, 9.90822049e-02, 1.97985172e-01, 2.96888138e-01,
#         3.95791105e-01, 4.94694072e-01, 5.93597038e-01, 6.92500005e-01,
#         7.91402971e-01, 8.90305938e-01, 9.89208905e-01]),
#  <a list of 10 Patch objects>)

# %%
#critical value for U-stats with sample size(20,20)=138
passed_count=0
for i in range (0,len(u_stats)):    
    if p_values[i]<=0.05 and u_stats[i]<=138:
        passed_count=passed_count+1
print("Number of tests passed=",passed_count,"/",num_samples,"tests runned")
# Out:
# Number of tests passed= 40 / 5000 tests runned

# %%
#critical value for U-stats with sample size(20,20)=138
passed_count=0
for i in range (0,len(u_stats)):    
    if p_values[i]<=0.1 and u_stats[i]<=138:
        passed_count=passed_count+1
print("Number of tests passed=",passed_count,"/",num_samples,"tests runned")
# Out:
# Number of tests passed= 64 / 5000 tests runned

# %% [markdown]
# # TGC

# %%
df_smolt_data['TGC'] = df_smolt_data['TGC'].str.replace(',', '.')

df_smolt_data['TGC'] = df_smolt_data['TGC'].astype(float)

# %%
df_smolt_data = df_smolt_data.dropna(subset=['TGC'])

df_smolt_data = df_smolt_data.reset_index(drop=True)

# %%
median_tgc = df_smolt_data['TGC'].median()


df_smolt_data['group'] = np.where(df_smolt_data['TGC'] < median_tgc, 0, 1)

# %%
df_smolt_data
# Out:
#      locus_id  fish_group_id  transfer_year  transfer_month  \
# 0     3046036           1052           2019               1
# 1     3046036           3918           2020              11
# 2     3046043            498           2019               7
# 3     3046052            847           2019               7
# 4     3046064            159           2019               4
# ..        ...            ...            ...             ...
# 713   7183882           6069           2022               6
# 714   7183884           6069           2022               6
# 715   7183889           6071           2022               6
# 716   7183892           6069           2022               6
# 717   7183893           6069           2022               6
#
#     transfer_month_year transfer_season  total_count  total_mortality_perc_90  \
# 0                1_2019          winter  46388,23077                 0.003943
# 1               11_2020          autumn  45241,16667                 0.007676
# 2                7_2019          summer  41131,79661                 0.027014
# 3                7_2019          summer  41498,96364                 0.018027
# 4                4_2019          spring  74572,21053                 0.011420
# ..                  ...             ...          ...                      ...
# 713              6_2022          summer     44712,52                 0.009889
# 714              6_2022          summer  44261,21622                 0.022363
# 715              6_2022          summer  44747,76389                 0.012813
# 716              6_2022          summer  44244,95833                 0.022576
# 717              6_2022          summer  43669,97015                 0.035174
#
#     transport_mortality_perc_90 nontransport_mortality_perc_90  ...       TGC  \
# 0                   0,000924979                    0,003017925  ...  0.951440
# 1                   0,005640632                    0,002035429  ...  1.181746
# 2                   0,022782874                    0,004230661  ...  0.883693
# 3                    0,01520579                    0,002821141  ...  1.163037
# 4                   0,002201648                    0,009218148  ...  1.409251
# ..                          ...                            ...  ...       ...
# 713                 0,004718095                    0,005170589  ...  1.115425
# 714                 0,014216011                    0,008146739  ...  0.876280
# 715                 0,002758736                    0,010054239  ...  0.768343
# 716                 0,015284297                    0,007291559  ...  0.876280
# 717                 0,028200436                    0,006973349  ...  1.001764
#
#     order_of_creation_from  strain  year_class  number_of_prod_cycle  \
# 0                        5     FLY          18                   C1B
# 1                       11     FLY          19                    C4
# 2                        3     LCY          18                    C3
# 3                        3     FLY          18                    C3
# 4                        7     FLY          18                   C2B
# ..                     ...     ...         ...                   ...
# 713                      4     FLY          21                    C3
# 714                      3     FLY          21                    C2
# 715                      3     FLY          21                    C2
# 716                      3     FLY          21                    C2
# 717                      3     FLY          21                    C2
#
#      place_first_feeding specific_treatment  two_place_of_first_feeding  \
# 0                     PH               None                           0
# 1                     PH                LUF                           0
# 2                    PGR               None                           1
# 3                    PGR               None                           1
# 4                     PH               None                           0
# ..                   ...                ...                         ...
# 713                   PH                LUF                           0
# 714                   PH                LUF                           0
# 715                   PH                LUF                           0
# 716                   PH                LUF                           0
# 717                   PH                LUF                           0
#
#      rolling_tempr_sum  group
# 0           783.761800      0
# 1           641.489505      1
# 2          2494.159925      0
# 3          1233.198278      1
# 4           813.066101      1
# ..                 ...    ...
# 713         736.388975      1
# 714        1001.523942      0
# 715        1073.508762      0
# 716        1001.523942      0
# 717        1022.942260      0
#
# [718 rows x 63 columns]

# %%
sns.scatterplot(data=df_smolt_data, x='total_mortality_perc_90', y='TGC', hue='group')
plt.show()

# %%
group_0 = df_smolt_data[df_smolt_data['group'] == 0]['total_mortality_perc_90']
group_1 = df_smolt_data[df_smolt_data['group'] == 1]['total_mortality_perc_90']

sample_std = np.std(group_0, ddof=1) 

n = len(group_0)  
population_std = sample_std * np.sqrt(n / (n - 1))

# %%
import statsmodels.api as sm
from statsmodels.stats.weightstats import ztest

group_0 = df_smolt_data[df_smolt_data['group'] == 0]['total_mortality_perc_90']
group_1 = df_smolt_data[df_smolt_data['group'] == 1]['total_mortality_perc_90']

population_std = sample_std 

z_statistic, p_value = ztest(group_0, group_1, value=0, alternative='two-sided', usevar='pooled', ddof=0)

# Print the z-statistic and p-value
print("Z-Statistic: ", z_statistic)
print("P-Value: ", p_value)
# Out:
# Z-Statistic:  0.15656234169421418
# P-Value:  0.8755897834329559

# %%
group_0 = df_smolt_data[df_smolt_data['group'] == 0]['total_mortality_perc_90']
group_1 = df_smolt_data[df_smolt_data['group'] == 1]['total_mortality_perc_90']
group_0 = np.nan_to_num(group_0)
group_1 = np.nan_to_num(group_1)

# %%
group_0 = df_smolt_data[df_smolt_data['group'] == 0]['total_mortality_perc_90']
group_1 = df_smolt_data[df_smolt_data['group'] == 1]['total_mortality_perc_90']

# Run t-test
t_statistic, p_value = stats.ttest_ind(group_0, group_1)

# Print the t-statistic and p-value
print("T-Statistic: ", t_statistic)
print("P-Value: ", p_value)
# Out:
# T-Statistic:  0.15634413623389776
# P-Value:  0.8758058392390291

# %%
group_0 = df_smolt_data[df_smolt_data['group'] == 0]['total_mortality_perc_90']
group_1 = df_smolt_data[df_smolt_data['group'] == 1]['total_mortality_perc_90']

statistic, p_value = mannwhitneyu(group_0, group_1, alternative='two-sided')

print("Mann-Whitney U statistic: ", statistic)
print("P-Value: ", p_value)
# Out:
# Mann-Whitney U statistic:  66794.0
# P-Value:  0.3971361626745382

# %%
mean_values = df_smolt_data.groupby('group')['total_mortality_perc_90'].mean()
median_values = df_smolt_data.groupby('group')['total_mortality_perc_90'].median()
#mode_values = df_smolt_data.groupby('group')['total_mortality_perc_90'].agg(pd.Series.mode)
min_values = df_smolt_data.groupby('group')['total_mortality_perc_90'].min()
max_values = df_smolt_data.groupby('group')['total_mortality_perc_90'].max()
# Print the results
print("Mean values:")
print(mean_values)
print("\nMedian values:")
print(median_values)
#print("\nMode values:")
#print(mode_values)
print("\nMinimum values:")
print(min_values)
print("\nMaximum values:")
print(max_values)
# Out:
# Mean values:
# group
# 0    0.015063
# 1    0.014907
# Name: total_mortality_perc_90, dtype: float64
#
# Median values:
# group
# 0    0.010629
# 1    0.010037
# Name: total_mortality_perc_90, dtype: float64
#
# Minimum values:
# group
# 0    0.003121
# 1    0.001601
# Name: total_mortality_perc_90, dtype: float64
#
# Maximum values:
# group
# 0    0.090181
# 1    0.084519
# Name: total_mortality_perc_90, dtype: float64

# %%
df_smolt_data[df_smolt_data.from_locus_population_id.isin([36794095])]['date_conf']
# Out:
# 798   2019-06-20
# Name: date_conf, dtype: datetime64[ns]

# %%
df_smolt_data.columns
# Out:
# Index(['locus_id', 'fish_group_id', 'transfer_year', 'transfer_month',
#        'transfer_month_year', 'transfer_season', 'total_count',
#        'total_mortality_perc_90', 'transport_mortality_perc_90',
#        'nontransport_mortality_perc_90', 'from_date', 'from_site_name',
#        'from_site_id', 'from_locus_id', 'from_locus_population_id',
#        'from_fish_group_id', 'from_fish_group_name', 'from_generation',
#        'from_year_class', 'from_count_stocking', 'from_avg_weight', 'to_date',
#        'type_id', 'to_site_name', 'to_site_id', 'to_locus_id',
#        'to_locus_population_id', 'to_fish_group_id', 'to_fish_group_name',
#        'to_generation', 'to_year_class', 'to_count_stocking', 'to_avg_weight',
#        'transfer_date', 'from_fish_group_count', 'days_btw_to_from',
#        'days_btw_to_transfer', 'vac_fish_count', 'vac_weight',
#        'days_btw_conf_event', '00000000000SRSv/Pha ', '000IPN+AAA+VVV+ISA/Pha',
#        'IPN+SRS+VIB+ASA+ISA/FAV', 'IPN+SRS+VVV+AAA+ISA/Pha',
#        'IPN+SRS+VVV+ISA/Fav   ', 'IPN-SRS-VVV-AAA-ISA/Cvt',
#        'vaccine_manufacturer_CENTROVET', 'vaccine_manufacturer_FAV',
#        'vaccine_manufacturer_PHARMAQ', 'uta', 'days_btw_transfer_conf',
#        'date_conf', 'SGR', 'TGC', 'order_of_creation_from', 'strain',
#        'year_class', 'number_of_prod_cycle', 'place_first_feeding',
#        'specific_treatment', 'two_place_of_first_feeding',
#        'rolling_tempr_sum'],
#       dtype='object')

# %%
temperatures['event_date'] = pd.to_datetime(temperatures['event_date'], format='%d.%m.%Y')

# Filter the dataframe based on the conditions
filtered_temperatures = temperatures[(temperatures['final_locus_population_id'] == 36794095) &
                                    (temperatures['event_date'] >= pd.to_datetime('27.09.2019', format='%d.%m.%Y')) &
                                    (temperatures['event_date'] <= pd.to_datetime('04.01.2020', format='%d.%m.%Y'))]

# Calculate the sum of rolling_tempr column in the filtered dataframe
sum_rolling_tempr = filtered_temperatures['rolling_tempr'].sum()

# %%
sum_rolling_tempr
# Out:
# 12.496666666666668
